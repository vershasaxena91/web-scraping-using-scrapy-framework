# %%
# importing libraries
from bs4 import BeautifulSoup
import requests
import json
import re
import urllib
import time
import logging

logger = logging.getLogger('scraper')
FORMAT = "[%(filename)s:%(lineno)s - %(funcName)20s() ] %(message)s"
logging.basicConfig(format=FORMAT)
#logger.setLevel(logging.DEBUG)
#logger.debug('your message') 

class web_scraping:
    def __init__(self, URL, data):
        self.URL = URL
        self.data = data

    # specifying user agent, You can use other user agents
    # available on the internet
        self.HEADERS = ({'User-Agent':
                'Mozilla/5.0 (X11; Linux x86_64)  AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
                                'Accept-Language': 'en-US, en;q=0.5'})
  
    # Making the HTTP Request
        self.webpage = requests.get(self.URL, headers=self.HEADERS)
  
    # Creating the Soup Object containing all data
        self.soup = BeautifulSoup(self.webpage.content, "lxml")
        

    # retreiving product title
    def product_title(self):
        try:
            title = self.soup.find("span", attrs={"id": 'productTitle'})          
            title_value = title.string        
            title_string = title_value.strip().replace(',', '')
            return title_string
        except AttributeError as e:
            logging.error("Exception occurred", exc_info=True)
            title_string = "NA"
            return title_string
  

    # retreiving product brand
    def brand(self):
        try:
            title_string = 'NA'
            if self.soup.find("td", attrs={"class": 'a-span9'}):         
                title = self.soup.find("td", attrs={"class": 'a-span9'})
                title = title.find("span", attrs={'class': 'a-size-base'})        
                title_string = title.text
                return title_string
            return title_string
        except AttributeError as e:
            logging.error("Exception occurred", exc_info=True)
            title_string = "NA"
            return title_string

    
    # retreiving product price
    def product_price(self):
        try:
            price = 'NA'
            if self.soup.find("span", attrs={'id': 'priceblock_ourprice'}):
                price = self.soup.find("span", attrs={'id': 'priceblock_ourprice'}).string.strip().replace(',', '')
                trim = re.compile(r'[^\d.,]+')
                result = trim.sub('', price)
                return result
            elif self.soup.find("span", attrs={'id': 'priceblock_dealprice'}):
                price = self.soup.find("span", attrs={'id': 'priceblock_dealprice'}).string.strip().replace(',', '')
                trim = re.compile(r'[^\d.,]+')
                result = trim.sub('', price)
                return result
            else:
                return price
        except AttributeError as e:
            logging.error("Exception occurred", exc_info=True)
            result = 'NA'
            return result
  
    
    # retreiving product offers
    def offers(self):
        try:
            offers = 'NA'
            if self.soup.find("span", attrs={'class': 'saving-prompt'}):
                offers = self.soup.find("span", attrs={'class': 'saving-prompt'}).text
                return str(int(re.search(r'\d+', offers).group()))
            return offers
        except AttributeError as e:
            logging.error("Exception occurred", exc_info=True)
            offers = "NA"
            return offers
    
    
    # retreiving strike product price
    def strike_product_price(self):
        try:
            price = 'NA'
            if self.soup.find("span", attrs={'class': 'priceBlockStrikePriceString a-text-strike'}):
                price = self.soup.find("span", attrs={'class': 'priceBlockStrikePriceString a-text-strike'}).text
                return str(float(re.search(r'\d+', price).group()))
            return price
        except AttributeError as e:
            logging.error("Exception occurred", exc_info=True)
            price = "NA"
            return price
    
    
    # retreiving product fullfilled
    def fullfilled(self):
        try:
            fullfilled = 'NA'
            if self.soup.find("span", attrs={'class': 'a-icon-text-fba'}):
                fullfilled_soup = self.soup.find("span", attrs={'class': 'a-icon-text-fba'})
                fullfilled = fullfilled_soup.text
                return fullfilled
            return fullfilled
        except AttributeError as e:
            logging.error("Exception occurred", exc_info=True)
            fullfilled = "NA"
            return fullfilled

    
    # retreiving product rating
    def rating(self):
        try:
            rating = self.soup.find("i", attrs={'class': 'a-icon a-icon-star a-star-4-5'}).string.strip().replace(',', '')
            return rating 
        except AttributeError:
            try:
                rating = self.soup.find("span", attrs={'class': 'a-icon-alt'}).string.strip().replace(',', '')
                return rating
            except Exception as e:
                logging.error("Exception occurred", exc_info=True)
                rating = "NA"
                return rating
          

    # retreiving product reviews
    def reviews(self):
        try:
            if self.soup.find("span", attrs={'id': 'acrCustomerReviewText'}):
                review_count = self.soup.find("span", attrs={'id': 'acrCustomerReviewText'}).string.strip().replace(',', '')
                return review_count
            return 'NA'
        except AttributeError as e:
            logging.error("Exception occurred", exc_info=True)
            review_count = "NA"
            return review_count

  
    # print availiblility status
    def availability(self):
        try:
            available = self.soup.find("div", attrs={'id': 'availability'})
            if available.find("span", attrs={'class': 'a-size-medium a-color-state'}):
                available = available.find("span", attrs={'class': 'a-size-medium a-color-state'}).string.strip().replace(',', '')
                return available
            return 'NA'  
        except AttributeError as e:
            logging.error("Exception occurred", exc_info=True)
            available = "NA"
            return available


    # retreiving product categories
    def categories(self):
        try:
            categories = []
            if self.soup.find("div", attrs={'id': 'showing-breadcrumbs_div'}):
                breadcrumbs_div = self.soup.find("div", attrs={'id': 'showing-breadcrumbs_div'})
                rating = breadcrumbs_div.find_all("span", attrs={'class': 'a-list-item'})
                for i in rating:
                    if len(i) > 1:
                        categories.append(i.text.strip().replace('›', ''))
                return categories
            return categories
        except AttributeError as e:
            logging.error("Exception occurred", exc_info=True)
            categories = "NA"
            return categories
            

    # retreiving product icons
    def icons(self):
        try: 
            icon_list = []
            fullfilled_soup = self.soup.find("div", attrs={'class': 'a-row icon-farm-wrapper'})
            icons = fullfilled_soup.text.strip().replace('\n', '').split('  ')
            for i in icons:
                if len(i) > 1:
                    icon_list.append(i)
            return icon_list
        except Exception as e:
            logging.error("Exception occurred", exc_info=True)
            icon_list = []
            return icon_list

    
    # retreiving product details
    def product_details(self):
        try:
            if self.soup.find("div", attrs={'id': 'detailBullets_feature_div'}):
                features_div = self.soup.find("div", attrs={'id': 'detailBullets_feature_div'})
                features_ordered = features_div.find_all("span", attrs={'class': 'a-list-item'})
                prod_feat = {}    
                try:
                    for i in features_ordered:
                        feat = i.text.strip().replace("\n", "").split(":")
                        if len(feat) == 2:
                            prod_feat[feat[0]] = feat[1]
                    return prod_feat
                except Exception as e:
                    logging.error("Exception occurred", exc_info=True)
                    pass
            return {}
        except AttributeError as e:
            logging.error("Exception occurred", exc_info=True)
            prod_feat = "NA"
            return prod_feat
            
    
    # retreiving product important infos
    def important_infos(self):
        try: 
            important_info = 'NA'
            if self.soup.find("div", attrs={'id': 'important-information'}):
                features_div = self.soup.find("div", attrs={'id': 'important-information'})
                important_info  = features_div.text.strip().replace("\n", "")
                return important_info
            return important_info
        except AttributeError as e:
            logging.error("Exception occurred", exc_info=True)
            important_info = "NA" 
            return important_info  

    
    # retreiving product bought together
    def bought_together(self):    
        try:
            bought_together = []
            bought_together_div = self.soup.find("div", attrs={'id': 'sims-consolidated-1_feature_div'})
            if bought_together_div:
                features_ordered = bought_together_div.find_all("img", alt=True)
                for i in features_ordered:
                    if i['alt'] != '':
                        bought_together.append(i['alt'])
            return bought_together
        except AttributeError as e:
            logging.error("Exception occurred", exc_info=True)
            bought_together = "NA"
            return bought_together
            
    
    # retreiving product subscription discount
    def subscription_discount(self):
        try: 
            subscription_discount = 'NA'
            if self.soup.find("span", attrs={'class': 'discountTextLeft'}):
                discount = self.soup.find("span", attrs={'class': 'discountTextLeft'})
                subscription_discount = discount.text
                return subscription_discount
            return subscription_discount
        except Exception as e:
            logging.error("Exception occurred", exc_info=True)
            subscription_discount = 'NA'
            return subscription_discount
            
  
    # retreiving product variations
    def variations(self):
        try:
            variations = []
            variations_div = self.soup.find("div", attrs={'id': 'variation_pattern_name'})
            if variations_div:
                variations_list = variations_div.find_all("img", attrs={'class': 'imgSwatch'})
                for i in variations_list:
                    variations.append(i['alt'])
            return variations
        except AttributeError as e:
            logging.error("Exception occurred", exc_info=True)
            variations = "NA"
            return variations
    

    # retreiving product data
    def Data(self):
        self.data["Url"] = self.URL
        self.data["product Title"] = self.product_title()
        self.data["brand"] = self.brand() 
        self.data["Products price"] = self.product_price()
        # trim = re.compile(r'[^\d.,]+')
        # result = trim.sub('', self.offers())
        self.data["Offer_Count"] = self.offers()
        # trim = re.compile(r'[^\d.,]+')
        # result = trim.sub('', self.strike_product_price())
        self.data["StrikeThrough_Products_price"] = self.strike_product_price()
        self.data["Fullfilled"] = self.fullfilled()
        self.data["Overall rating"] = self.rating()
        self.data["Total reviews"] = self.reviews()
        self.data["Availability"] = self.availability()
        self.data["Category Tree"] = self.categories()
        self.data["icons"] = self.icons()
        self.data["Product_Details"] = self.product_details()
        self.data["misc_info"] = self.important_infos()
        self.data["bought_together"] = self.bought_together()
        self.data["subscription_discount"] = self.subscription_discount()
        self.data["variations"] = self.variations()
        return self.data
    

    def complete_data(self):
        data = []
        data.append(self.product_title())
        data.append(self.brand())
        data.append(self.product_price())
        data.append(self.offers())
        data.append(self.strike_product_price())
        data.append(self.fullfilled())
        data.append(self.rating())
        data.append(self.reviews())
        data.append(self.availability())
        data.append(self.categories())
        data.append(self.icons())
        data.append(self.product_details())
        data.append(self.important_infos())
        data.append(self.bought_together())
        data.append(self.subscription_discount())
        data.append(self.variations())
        return data

# %%
import pandas as pd
df = pd.read_csv("sh_url.csv")
urls = df['URL']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
complete_data = []
for links in urls[80:160]:
    print("-"*50)
    data = {}
    print(links)
    try: 
        product_info = web_scraping(links,data).Data()
        print(product_info)
        complete_data.append(product_info)
        time.sleep(5)
    except Exception as e:
        logging.error("Exception occurred", exc_info=True)
        print("-"*20 + " Exception " + "-"*20)
        print(links)
        print(e)
# Out:
# --------------------------------------------------
# https://www.amazon.in/LOccitane-Aromachologie-Repairing-Shampoo-300ml/dp/B00E6KILTC/ref=sxin_10?asc_contentid=amzn1.osa.616a1218-209a-4c6e-b84c-511fbc004b38.A21TJRUUN4KGV.en_IN&asc_contenttype=article&ascsubtag=amzn1.osa.616a1218-209a-4c6e-b84c-511fbc004b38.A21TJRUUN4KGV.en_IN&creativeASIN=B00E6KILTC&cv_ct_cx=shampoo&cv_ct_id=amzn1.osa.616a1218-209a-4c6e-b84c-511fbc004b38.A21TJRUUN4KGV.en_IN&cv_ct_pg=search&cv_ct_we=asin&cv_ct_wn=osp-single-source-pecos-desktop&dchild=1&keywords=shampoo&linkCode=oas&pd_rd_i=B00E6KILTC&pd_rd_r=2dc6b676-5de4-46d9-965d-d5f5ec455d15&pd_rd_w=t9M3P&pd_rd_wg=av0AI&pf_rd_p=6567d3a4-28dd-430b-a035-b0af9623dfa4&pf_rd_r=1SK879FYV6GQC83CRS5N&qid=1622109910&sr=1-4-c84eb971-91f2-4a4d-acce-811265c24254&tag=timeszoom-21
# {'Url': 'https://www.amazon.in/LOccitane-Aromachologie-Repairing-Shampoo-300ml/dp/B00E6KILTC/ref=sxin_10?asc_contentid=amzn1.osa.616a1218-209a-4c6e-b84c-511fbc004b38.A21TJRUUN4KGV.en_IN&asc_contenttype=article&ascsubtag=amzn1.osa.616a1218-209a-4c6e-b84c-511fbc004b38.A21TJRUUN4KGV.en_IN&creativeASIN=B00E6KILTC&cv_ct_cx=shampoo&cv_ct_id=amzn1.osa.616a1218-209a-4c6e-b84c-511fbc004b38.A21TJRUUN4KGV.en_IN&cv_ct_pg=search&cv_ct_we=asin&cv_ct_wn=osp-single-source-pecos-desktop&dchild=1&keywords=shampoo&linkCode=oas&pd_rd_i=B00E6KILTC&pd_rd_r=2dc6b676-5de4-46d9-965d-d5f5ec455d15&pd_rd_w=t9M3P&pd_rd_wg=av0AI&pf_rd_p=6567d3a4-28dd-430b-a035-b0af9623dfa4&pf_rd_r=1SK879FYV6GQC83CRS5N&qid=1622109910&sr=1-4-c84eb971-91f2-4a4d-acce-811265c24254&tag=timeszoom-21', 'product Title': "L'Occitane Damaged Hair Intensive Repairing Shampoo 300ml", 'brand': "L'OCCITANE", 'Products price': '1950.00', 'Offer_Count': 'NA', 'StrikeThrough_Products_price': 'NA', 'Fullfilled': 'NA', 'Overall rating': '4.5 out of 5 stars', 'Total reviews': '737 ratings', 'Availability': 'NA', 'Category Tree': [], 'icons': ['Pay on Delivery', 'Not Returnable', 'Amazon Delivered', 'No-Contact Delivery'], 'Product_Details': {'Is Discontinued By Manufacturer\u200f': '\u200eNo', 'Product Dimensions\u200f': '\u200e5.89 x 5.89 x 16.69 cm; 300 Grams', 'Date First Available\u200f': '\u200e22 August 2014', 'Manufacturer\u200f': "\u200eL'Occitane", 'ASIN\u200f': '\u200eB00E6KILTC', 'Item model number\u200f': '\u200e17SH300G18', 'Country of Origin\u200f': '\u200eFrance', 'Item Weight\u200f': '\u200e300 g', 'Item Dimensions LxWxH\u200f': '\u200e5.9 x 5.9 x 16.7 Centimeters', 'Net Quantity\u200f': '\u200e300.0 millilitre', 'Best Sellers Rank': '#30,285 in Beauty (See Top 100 in Beauty) #1,946 in Shampoos (Beauty)'}, 'misc_info': 'NA', 'bought_together': [], 'subscription_discount': 'NA', 'variations': []}
# --------------------------------------------------
# https://www.amazon.in/LOreal-Paris-Total-Repair-Shampoo/dp/B08CSHBPD5/ref=sr_1_8?dchild=1&keywords=shampoo&qid=1622109910&sr=8-8
# {'Url': 'https://www.amazon.in/LOreal-Paris-Total-Repair-Shampoo/dp/B08CSHBPD5/ref=sr_1_8?dchild=1&keywords=shampoo&qid=1622109910&sr=8-8', 'product Title': "L'Oreal Paris Total Repair 5 Shampoo 1 Litre", 'brand': "L'Oreal Paris", 'Products price': '519.00', 'Offer_Count': '4', 'StrikeThrough_Products_price': '796.0', 'Fullfilled': 'Fulfilled', 'Overall rating': '4.3 out of 5 stars', 'Total reviews': '9365 ratings', 'Availability': 'NA', 'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'], 'icons': ['Pay on Delivery', 'Not Returnable', 'Amazon Delivered', 'No-Contact Delivery'], 'Product_Details': {'Product Dimensions\u200f': '\u200e10.5 x 7.8 x 24.8 cm; 1.13 Kilograms', 'Date First Available\u200f': '\u200e10 July 2020', 'Manufacturer\u200f': "\u200eL'Oreal India Pvt. Ltd., Loreal India Pvt Ltd, Chakan, Pune - 410 501", 'ASIN\u200f': '\u200eB08CSHBPD5', 'Item part number\u200f': '\u200eHESTR900-00', 'Country of Origin\u200f': '\u200eIndia', 'Item Weight\u200f': '\u200e1 kg 130 g', 'Item Dimensions LxWxH\u200f': '\u200e10.5 x 7.8 x 24.8 Centimeters', 'Net Quantity\u200f': '\u200e1000.0 millilitre', 'Generic Name\u200f': '\u200eTotal Repair 5 Shampoo', 'Best Sellers Rank': '#20 in Beauty (See Top 100 in Beauty) #4 in Shampoos (Beauty)'}, 'misc_info': 'Important informationIngredients:AQUA / WATER, SODIUM LAURETH SULFATE, COCO-BETAINE, DIMETHICONE, GLYCOL DISTEARATE, SODIUM CHLORIDE, GUAR HYDROXYPROPYLTRIMONIUM CHLORIDE, QUATERNIUM-33, SODIUM BENZOATE, HYDROXYPROPYLTRIMONIUM HYDROLYZED WHEAT PROTEIN, SODIUM HYDROXIDE, PPG-5-CETETH-20, ARGININE, BEHENTRIMONIUM METHOSULFATE, SALICYLIC ACID, POLYQUATERNIUM-7, LIMONENE, LINALOOL, BENZYL SALICYLATE, BENZYL ALCOHOL, 2-OLEAMIDO-1, 3-OCTADECANEDIOL, CARBOMER, SERINE, BUTYLPHENYL METHYLPROPIONAL, CETYL ALCOHOL, CITRIC ACID, GLUTAMIC ACID, HEXYL CINNAMAL, GLYCERYL LINOLEATE, GLYCERYL OLEATE, GLYCERYL LINOLENATE, PARFUM / FRAGRANCE, (F.I.L. C170134/1)', 'bought_together': ["L'Oreal Paris Total Repair 5 Shampoo, 1 Litre", "L'Oreal Paris Total Repair 5 Conditioner, 192.5ml", "L'Oreal Paris Total Repair 5 Serum, 80ml"], 'subscription_discount': '5%', 'variations': ['Shampoo', 'Shampoo & Conditioner', 'Shampoo + Conditioner', 'Shampoo + Conditioner + Total repair']}
# --------------------------------------------------
# https://www.amazon.in/LOreal-Paris-Dream-Lengths-Shampoo/dp/B08T2Y2Q4T/ref=sr_1_9?dchild=1&keywords=shampoo&qid=1622109910&sr=8-9
# {'Url': 'https://www.amazon.in/LOreal-Paris-Dream-Lengths-Shampoo/dp/B08T2Y2Q4T/ref=sr_1_9?dchild=1&keywords=shampoo&qid=1622109910&sr=8-9', 'product Title': "L'Oreal Paris Dream Lengths Shampoo 192.5 ml", 'brand': "L'Oreal Paris", 'Products price': '141.00', 'Offer_Count': '4', 'StrikeThrough_Products_price': '149.0', 'Fullfilled': 'Fulfilled', 'Overall rating': '4.2 out of 5 stars', 'Total reviews': '2444 ratings', 'Availability': 'NA', 'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'], 'icons': ['Not Returnable', 'Amazon Delivered', 'No-Contact Delivery'], 'Product_Details': {'Product Dimensions\u200f': '\u200e6.8 x 3.3 x 18 cm; 130 Grams', 'Date First Available\u200f': '\u200e14 January 2021', 'Manufacturer\u200f': "\u200eL'Oréal Paris India Pvt Ltd., Loreal India Pvt Ltd, Chakan, Pune - 410501", 'ASIN\u200f': '\u200eB08T2Y2Q4T', 'Item part number\u200f': '\u200eHESDL175-00', 'Country of Origin\u200f': '\u200eIndia', 'Packer\u200f': '\u200eLoreal India Pvt Ltd, Chakan, Pune - 410501', 'Importer\u200f': '\u200eLoreal Paris India Pvt. Ltd.', 'Item Weight\u200f': '\u200e130 g', 'Item Dimensions LxWxH\u200f': '\u200e6.8 x 3.3 x 18 Centimeters', 'Net Quantity\u200f': '\u200e192.5 millilitre', 'Included Components\u200f': '\u200eShampoo', 'Generic Name\u200f': '\u200eDream Lengths Shampoo', 'Best Sellers Rank': '#79 in Beauty (See Top 100 in Beauty) #11 in Shampoos (Beauty)'}, 'misc_info': 'NA', 'bought_together': ["L'Oreal Paris Dream Lengths Shampoo, 192.5 ml", "L'Oreal Paris Dream Lengths Conditioner, 192.5 ml", "L'Oréal Paris Dream Lengths No Haircut Cream Leave-In Conditioner, 200ml"], 'subscription_discount': 'NA', 'variations': []}
# --------------------------------------------------
# https://www.amazon.in/LOreal-Paris-Extraordinary-Shampoo-640ml/dp/B074VG8ZH8/ref=sr_1_10?dchild=1&keywords=shampoo&qid=1622109910&sr=8-10
# {'Url': 'https://www.amazon.in/LOreal-Paris-Extraordinary-Shampoo-640ml/dp/B074VG8ZH8/ref=sr_1_10?dchild=1&keywords=shampoo&qid=1622109910&sr=8-10', 'product Title': "L'Oreal Paris Extraordinary Clay Shampoo 704 ml (640 ml + 64 ml)", 'brand': 'NA', 'Products price': '432.00', 'Offer_Count': '4', 'StrikeThrough_Products_price': '450.0', 'Fullfilled': 'Fulfilled', 'Overall rating': '4.3 out of 5 stars', 'Total reviews': '1253 ratings', 'Availability': 'NA', 'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos
Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'], 'icons': ['Pay on Delivery', 'Not Returnable', 'Amazon Delivered', 'No-Contact Delivery'], 'Product_Details': {'Product Dimensions\u200f': '\u200e0.1 x 9.2 x 25.9 cm; 580 Grams', 'Date First Available\u200f': '\u200e27 June 2018', 'Manufacturer\u200f': '\u200eHUL', 'ASIN\u200f': '\u200eB07F2QCLP2', 'Item part number\u200f': '\u200e11616', 'Country of Origin\u200f': '\u200eIndia', 'Item Weight\u200f': '\u200e580 g', 'Item Dimensions LxWxH\u200f': '\u200e1 x 92 x 259 Millimeters', 'Net Quantity\u200f': '\u200e580.0 millilitre', 'Best Sellers Rank': '#300 in Beauty (See Top 100 in Beauty) #47 in Shampoos (Beauty)'}, 'misc_info': 'Important informationSafety Information:Avoid contact with eyes. In case of contact rinse thoroughly with waterIndications:• Apply to your wet hair and gently massage and work it into a lather. • After the application rinse thoroughly. • After rinsing shampoo, use the TRESemme Conditioner.Directions:Store in a cool and dry place.', 'bought_together': ['Tresemme Hair Fall Defence Shampoo, For Strong Hair, With Keratin Protein, Prevent Hair Fall due to Breakage, 580 ml', 'Tresemme Hair Fall Defense Conditioner, With Keratin Protein, Prevents Hair Fall due to Breakage, Gives Longer & Stronger Hair, 190 ml', 'Tresemme Keratin Smooth Conditioner, With Keratin And Argan Oil For Straighter, Smoother And Shinier Hair, 190 ml'], 'subscription_discount': 'NA', 'variations': ['Shampoo', 'Shampoo 580ml + Conditioner 190ml', 'Hairfall Defense Shampoo + Shampoo, 340ml', 'Hairfall Defense Shampoo + Shampoo, 580ml', 'Hairfall Defense Shampoo + Shampoo, 650ml', 'Hairfall Defense Shampoo + Shine Shampoo', 'Shampoo + Conditioner', 'Shampoo, 580ml + Body Lotion, 200ml', 'Shampoo, 580ml + Daily Shine Conditioner', 'Shampoo, 580ml + Hair Therapy Conditioner']}
# --------------------------------------------------
# https://www.amazon.in/TRESemme-Hair-Defence-Shampoo-1000ml/dp/B07L3YNL2V/ref=sr_1_12?dchild=1&keywords=shampoo&qid=1622109910&sr=8-12
# {'Url': 'https://www.amazon.in/TRESemme-Hair-Defence-Shampoo-1000ml/dp/B07L3YNL2V/ref=sr_1_12?dchild=1&keywords=shampoo&qid=1622109910&sr=8-12', 'product Title': 'Tresemme Hair Fall Defence Shampoo For Strong Hair With Keratin Protein Prevents Hair Fall due to Breakage 1 Ltr', 'brand': 'NA', 'Products price': '525.00', 'Offer_Count': '4', 'StrikeThrough_Products_price': '648.0', 'Fullfilled': 'Fulfilled', 'Overall rating': '4.4 out of 5 stars', 'Total reviews': '3940 ratings', 'Availability': 'NA', 'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'], 'icons': ['Pay on Delivery', 'Not Returnable', 'Amazon Delivered', 'No-Contact Delivery'], 'Product_Details': {'Product Dimensions\u200f': '\u200e22.9 x 10.2 x 6.4 cm; 1 Kilograms', 'Date First Available\u200f': '\u200e4 December 2018', 'Manufacturer\u200f': '\u200eHUL', 'ASIN\u200f': '\u200eB07L3YNL2V', 'Item part number\u200f': '\u200e26119', 'Country of Origin\u200f': '\u200eIndia', 'Item Weight\u200f': '\u200e1 kg', 'Item Dimensions LxWxH\u200f': '\u200e22.9 x 10.2 x 6.4 Centimeters', 'Net Quantity\
# {'Url': 'https://www.amazon.in/Biotique-Protein-Intensive-Regrowth-Treatment/dp/B07YWMQRNJ/ref=sr_1_14?dchild=1&keywords=shampoo&qid=1622109910&sr=8-14', 'product Title': 'Biotique Bio Kelp Protein Shampoo for Falling Hair Intensive Hair Regrowth Treatment 340ml', 'brand': 'Biotique', 'Products price': '209.00', 'Offer_Count': '4', 'StrikeThrough_Products_price': '299.0', 'Fullfilled': 'Fulfilled', 'Overall rating': '4.1 out of 5 stars', 'Total reviews': '7945 ratings', 'Availability': 'NA', 'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'], 'icons': ['Not Returnable', 'Amazon Delivered', 'No-Contact Delivery'], 'Product_Details': {'Is Discontinued By Manufacturer\u200f': '\u200eNo', 'Product Dimensions\u200f': '\u200e19.6 x 7.9 x 4.6 cm; 320 Grams', 'Date First Available\u200f': '\u200e9 October 2019', 'Manufacturer\u200f': '\u200eBio Veda Action Research Company', 'ASIN\u200f': '\u200eB07YWMQRNJ', 'Item part number\u200f': '\u200eNEWRETWH0058', 'Country of Origin\u200f': '\u200eIndia', 'Importer\u200f': '\u200eBio Veda Action Research Company, Khasra No 439/42 Mauja Rampur Ghat, Tehsil-Paonta Sahib, Dist-Sirmour, Pin 173025 (H.P), India', 'Item Weight\u200f': '\u200e320 g', 'Item Dimensions LxWxH\u200f': '\u200e19.6 x 7.9 x 4.6 Centimeters', 'Net Quantity\u200f': '\u200e340.0 millilitre', 'Generic Name\u200f': '\u200eKelp Protein Shampoo For Falling Hair', 'Best Sellers Rank': '#192 in Beauty (See Top 100 in Beauty) #26 in Shampoos (Beauty)'}, 'misc_info': 'NA', 'bought_together': ['Biotique Bio Kelp Protein Shampoo for Falling Hair Intensive Hair Regrowth Treatment, 340ml', 'Biotique Bio Mountain Ebony Vitalizing Serum For Falling Hair Intensive Hair Growth Treatment, 120ML', 'Biotique Bio Bhringraj Therapeutic Hair Oil for Falling Hair Intensive Hair Regrowth Treatment, 120ml'], 'subscription_discount': '5%', 'variations': []}
# --------------------------------------------------
# https://www.amazon.in/Nyle-Anti-Hairfall-Shampoo-800ml/dp/B01M0PCSDR/ref=sr_1_15?dchild=1&keywords=shampoo&qid=1622109910&sr=8-15
# {'Url': 'https://www.amazon.in/Nyle-Anti-Hairfall-Shampoo-800ml/dp/B01M0PCSDR/ref=sr_1_15?dchild=1&keywords=shampoo&qid=1622109910&sr=8-15', 'product Title': 'Nyle Anti-Hairfall Shampoo 800ml', 'brand': 'NA', 'Products price': '214.00', 'Offer_Count': '4', 'StrikeThrough_Products_price': '305.0', 'Fullfilled': 'Fulfilled', 'Overall rating': '4.2 out of 5 stars', 'Total reviews': '2937 ratings', 'Availability': 'NA', 'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'], 'icons': ['Not Returnable', 'Amazon Delivered', 'No-Contact Delivery'], 'Product_Details': {'Is Discontinued By Manufacturer\u200f': '\u200eNo', 'Product Dimensions\u200f': '\u200e9.4 x 6.3 x 24.5 cm; 883 Grams', 'Date First Available\u200f': '\u200e6 October 2016', 'Manufacturer\u200f': '\u200eCavinKare Pvt. Ltd, CavinKare Pvt. Ltd., Cavinville, No. 12, Cenotaph Road, Chennai - 600 018, 1800 419 0671', 'ASIN\u200f': '\u200eB01M0PCSDR', 'Item part number\u200f': '\u200eNAH0800R', 'Country of Origin\u200f': '\u200eIndia', 'Packer\u200f': '\u200eCavinKare Pvt. Ltd., Cavinville, No. 12, Cenotaph Road, Chennai - 600 018, 1800 419 0671', 'Item Weight\u200f': '\u200e883 g', 'Item Dimensions LxWxH\u200f': '\u200e9.4 x 6.3 x 24.5 Centimeters', 'Net Quantity\u200f': '\u200e800.0 millilitre', 'Included Components\u200f': '\u200eShampoo', 'Generic Name\u200f': '\u200eShampoo', 'Best Sellers Rank': '#202 in Beauty (See Top 100 in Beauty) #31 in Shampoos (Beauty)'}, 'misc_info': 'NA', 'bought_together': [], 'subscription_discount': '5%', 'variations': ['Anti-Hairfall', 'Anti-Hairfall + Damage Repair', 'Anti-Hairfall + Damage Repair + Dryness Hydration', 'Anti-Hairfall + Dryness Hydration', 'Anti-Hairfall + Pollution Shield', 'Anti-Hairfall + Volume Enhance']}
# --------------------------------------------------
# https://www.amazon.in/Khadi-Natural-Bhringraj-Shampoo-Cleanser/dp/B01N3YESMI/ref=sr_1_16?dchild=1&keywords=shampoo&qid=1622109910&sr=8-16
# {'Url': 'https://www.amazon.in/Khadi-Natural-Bhringraj-Shampoo-Cleanser/dp/B01N3YESMI/ref=sr_1_16?dchild=1&keywords=shampoo&qid=1622109910&sr=8-16', 'product Title': 'KHADI NATURAL Ayurvedic Amla and Bhringraj Hair Cleanser(Shampoo) SLS and Paraben Free 210ml', 'brand': 'KHADI NATURAL', 'Products price': '160.00', 'Offer_Count': '4', 'StrikeThrough_Products_price': '235.0', 'Fullfilled': 'Fulfilled', 'Overall rating': '4.0 out of 5 stars', 'Total reviews': '3130 ratings', 'Availability': 'NA', 'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'], 'icons': ['Not Returnable', 'Amazon Delivered', 'No-Contact Delivery'], 'Product_Details': {'Is Discontinued By Manufacturer\u200f': '\u200eNo', 'Product Dimensions\u200f': '\u200e15 x 4.2 x 4.2 cm; 211 Grams', 'Date First Available\u200f': '\u200e18 October 2013', 'Manufacturer\u200f': '\u200eKhadi Naturals', 'ASIN\u200f': '\u200eB01N3YESMI', 'Country of Origin\u200f': '\u200eIndia', 'Item Weight\u200f': '\u200e211 g', 'Item Dimensions LxWxH\u200f': '\u200e15 x 4.2 x 4.2 Centimeters', 'Net Quantity\u200f': '\u200e210.0 millilitre', 'Included Components\u200f': '\u200eLabel, shrink wrap, carton', 'Generic Name\u200f': '\u200eAyurvedic Amla and Bhringraj Hair Cleanser (Shampoo) Sls and Paraben Free', 'Best Sellers Rank': '#167 in Beauty (See Top 100 in Beauty) #22 in Shampoos (Beauty)'}, 'misc_info': 'Important informationLegal Disclaimer:100% KHADI NATURAL PRODUCT ORIGINAL PACKING MFG: JUNE 2016 EXP : 2 YEARS', 'bought_together': ['KHADI NATURAL Ayurvedic Amla and Bhringraj Hair Cleanser(Shampoo), SLS and Paraben Free, 210ml', 'Khadi NaturalÂ\xa0Shikakai and Honey Herbal Hair Conditioner, SLS and Paraben Free, 210ml', 'KHADI NATURAL Neem and Aloevera Herbal Hair Cleanser/Shampoo, SLS and Paraben Free, 210ml'], 'subscription_discount': 'NA', 'variations': ['Hair oil', 'Hair oil + Hair cleanser']}
Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'], 'icons': ['Not Returnable', 'Amazon Delivered', 'No-Contact Delivery'], 'Product_Details': {'Is Discontinued By Manufacturer\u200f': '\u200eNo', 'Product Dimensions\u200f': '\u200e7.6 x 4.2 x 22 cm; 340 Grams', 'Date First Available\u200f': '\u200e16 October 2013', 'Manufacturer\u200f': '\u200ePritam International Pvt Ltd.', 'ASIN\u200f': '\u200eB008KH6VP8', 'Item model number\u200f': '\u200eShampoo_51', 'Country of Origin\u200f': '\u200eIndia', 'Item Weight\u200f': '\u200e340 g', 'Item Dimensions LxWxH\u200f': '\u200e7.6 x 4.2 x 22 Centimeters', 'Net Quantity\u200f': '\u200e340.0 millilitre', 'Included Components\u200f': '\u200eShampoo', 'Generic Name\u200f': '\u200eShampoo', 'Best Sellers Rank': '#215 in Beauty (See Top 100 in Beauty) #32 in Shampoos (Beauty)'}, 'misc_info': 'NA', 'bought_together': [], 'subscription_discount': '5%', 'variations': []}
# --------------------------------------------------
# https://www.amazon.in/Dove-Intense-Repair-Shampoo-1L/dp/B07H9SV624/ref=sr_1_19?dchild=1&keywords=shampoo&qid=1622109910&smid=AT95IG9ONZD7S&sr=8-19
# {'Url': 'https://www.amazon.in/Dove-Intense-Repair-Shampoo-1L/dp/B07H9SV624/ref=sr_1_19?dchild=1&keywords=shampoo&qid=1622109910&smid=AT95IG9ONZD7S&sr=8-19', 'product Title': 'Dove Intense Repair Shampoo For Damaged HairEnriched with Fiber Actives Repairs Hair Damage  Makes Hair Smooth And Strong 1 Ltr', 'brand': 'Dove', 'Products price': '475.80', 'Offer_Count': '4', 'StrikeThrough_Products_price': '690.0', 'Fullfilled': 'Fulfilled', 'Overall rating': '4.4 out of 5 stars', 'Total reviews': '13017 ratings', 'Availability': 'In stock on June 20 2021.', 'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'], 'icons': ['Pay on Delivery', 'Not Returnable', 'Amazon Delivered', 'No-Contact Delivery'], 'Product_Details': {'Product Dimensions\u200f': '\u200e7.2 x 10.6 x 23.4 cm; 1.14 Kilograms', 'Date First Available\u200f': '\u200e13 September 2018', 'Manufacturer\u200f': '\u200eHUL', 'ASIN\u200f': '\u200eB07H9SV624', 'Item part number\u200f': '\u200e12995', 'Country of Origin\u200f': '\u200eIndia', 'Item Weight\u200f': '\u200e1 kg 140 g', 'Item Dimensions LxWxH\u200f': '\u200e7.2 x 10.6 x 23.4 Centimeters', 'Net Quantity\u200f': '\u200e1000.0 millilitre', 'Best Sellers Rank': '#29 in Beauty (See Top 100 in Beauty) #5 in Shampoos (Beauty)'}, 'misc_info': "Important informationDirections:Completely soak your hair and massage your shampoo gently over your scalp. Rinse it out well. Usually rinse and repeat? For daily shampooing the rinse and repeat rule isn't actually necessary (unless you've been trigger-happy with the hairspray), so just once will do", 'bought_together': ['Dove Intense Repair Shampoo For Damaged Hair,Enriched with Fiber Actives, Repairs Hair Damage , Makes Hair Smooth And Strong,', 'Dove Intense Repair Conditioner For Damaged, Frizzy Hair, Deep Nourishment For Healthy, For Smooth, Frizz Protected Hair, 175', 'Dove Daily Shine Shampoo - For Dull And Frizzy Hair, Makes Hair Soft, Shiny And Smooth, For Daily Use, 340 ml'], 'subscription_discount': '5%', 'variations': []}
# --------------------------------------------------
# https://www.amazon.in/Sunsilk-Almond-Honey-Shampoo-370/dp/B08HSS5BY1/ref=sr_1_20?dchild=1&keywords=shampoo&qid=1622109910&sr=8-20
# {'Url': 'https://www.amazon.in/Sunsilk-Almond-Honey-Shampoo-370/dp/B08HSS5BY1/ref=sr_1_20?dchild=1&keywords=shampoo&qid=1622109910&sr=8-20', 'product Title': 'Sunsilk Almond & Honey Shampoo 370 ml', 'brand': 'Sunsilk', 'Products price': '175.77', 'Offer_Count': '4', 'StrikeThrough_Products_price': '189.0', 'Fullfilled': 'Fulfilled', 'Overall rating': '4.1 out of 5 stars', 'Total reviews': '1031 ratings', 'Availability': 'NA', 'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'], 'icons': ['Not Returnable', 'Amazon Delivered', 'No-Contact Delivery'], 'Product_Details': {'Product Dimensions\u200f': '\u200e6.2 x 4.4 x 21.5 cm; 400 Grams', 'Date First Available\u200f': '\u200e10 September 2020', 'Manufacturer\u200f': '\u200eYODEVA PLASTICS (P) LTD, MFG. BY YODEVA PLASTICS (P) LTD., EPIP , PHASE 2 , PLOT NO 81 , THANA , BADDI 173205 , DIST. SOLAN , HIMACHAL PRADESH. M HIM/COS/04/41.', 'ASIN\u200f': '\u200eB08HSS5BY1', 'Item part number\u200f': '\u200e26338', 'Country of Origin\u200f': '\u200eIndia', 'Item Weight\u200f': '\u200e400 g', 'Item Dimensions LxWxH\u200f': '\u200e6.2 x 4.4 x 21.5 Centimeters', 'Net Quantity\u200f': '\u200e370.0 millilitre', 'Generic Name\u200f': '\u200eAlmond & Honey Shampoo', 'Best Sellers Rank': '#1,768 in Beauty (See Top 100 in Beauty) #199 in Shampoos (Beauty)'}, 'misc_info': 'NA', 'bought_together': [], 'subscription_discount': 'NA', 'variations': []}
# --------------------------------------------------
# https://www.amazon.in/Herbal-Essences-Eucalyptus-Sulfates-Silicone-Free/dp/B0831B5S96/ref=sr_1_21_sspa?dchild=1&keywords=shampoo&qid=1622109910&sr=8-21-spons&psc=1&qualifier=1622109910&id=8102039085665146&widgetName=sp_mtf
# {'Url': 'https://www.amazon.in/Herbal-Essences-Eucalyptus-Sulfates-Silicone-Free/dp/B0831B5S96/ref=sr_1_21_sspa?dchild=1&keywords=shampoo&qid=1622109910&sr=8-21-spons&psc=1&qualifier=1622109910&id=8102039085665146&widgetName=sp_mtf', 'product Title': 'Herbal Essences Real Aloe & Eucalyptus Shampoo Sulfates Paraben and Silicone-Free 400ML', 'brand': 'Herbal Essences', 'Products price': '638.00', 'Offer_Count': '4', 'StrikeThrough_Products_price': '750.0', 'Fullfilled': 'Fulfilled', 'Overall rating': '4.0 out of 5 stars', 'Total reviews': '20 ratings', 'Availability': 'NA', 'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'], 'icons': ['Pay on Delivery', 'Not Returnable', 'Amazon Delivered', 'No-Contact Delivery'], 'Product_Details': {'Product Dimensions\u200f': '\u200e7.5 x 4.5 x 20.4 cm; 400 Grams', 'Date First Available\u200f': '\u200e14 December 2020', 'Manufacturer\u200f': '\u200eProcter & Gamble, Procter & Gamble Manufacturing (Thailand) Ltd. Chachoengsao, 24180 Thailand.', 'ASIN\u200f': '\u200eB0831B5S96', 'Item part number\u200f': '\u200e82320232', 'Country of Origin\u200f': '\u200eThailand', 'Packer\u200f': '\u200eProcter & Gamble Manufacturing (Thailand) Ltd. Chachoengsao, 24180 Thailand.', 'Importer\u200f': '\u200eIndia P&G plaza, Cardinal Gracias Road, Chakala, Andheri (E), Mumbai - 400099 India', 'Item Weight\u200f': '\u200e400 g', 'Item Dimensions LxWxH\u200f': '\u200e7.5 x 4.5 x 20.4 Centimeters', 'Net Quantity\u200f': '\u200e400.0 millilitre', 'Included Components\u200f': '\u200eShampoo', 'Generic Name\u200f': '\u200ePotent Aloe & Eucalyptus Shampoo, Sulphates, Silicones and Paraben Free', 'Best Sellers Rank': '#3,813 in Beauty (See Top 100 in Beauty) #355 in Shampoos (Beauty)'}, 'misc_info': 'NA', 'bought_together': [], 'subscription_discount': 'NA', 'variations': []}
# --------------------------------------------------
# https://www.amazon.in/LOrealProfessionnel-Serie-Expert-OX-Shampoo300ml/dp/B06Y3WVH2X/ref=sr_1_22_sspa?dchild=1&keywords=shampoo&qid=1622109910&sr=8-22-spons&psc=1&qualifier=1622109910&id=8102039085665146&widgetName=sp_mtf
# {'Url': 'https://www.amazon.in/LOrealProfessionnel-Serie-Expert-OX-Shampoo300ml/dp/B06Y3WVH2X/ref=sr_1_22_sspa?dchild=1&keywords=shampoo&qid=1622109910&sr=8-22-spons&psc=1&qualifier=1622109910&id=8102039085665146&widgetName=sp_mtf', 'product Title': "L'Oréal Professionnel Serie Expert Vitamino Shampoo | For coloured hair |Protects hair colour from fading & adds shine |With Antioxidant properties", 'brand': "L'Oréal Professionnel", 'Products price': '665.00', 'Offer_Count': 'NA', 'StrikeThrough_Products_price': 'NA', 'Fullfilled': 'NA', 'Overall rating': '4.4 out of 5 stars', 'Total reviews': '818 ratings', 'Availability': 'NA', 'Category Tree': [], 'icons': ['Pay on Delivery', 'Not Returnable', 'Amazon Delivered', 'No-Contact Delivery'], 'Product_Details': {'Batteries\u200f': '\u200e1 A batteries required.', 'Is Discontinued By Manufacturer\u200f': '\u200eNo', 'Product Dimensions\u200f': '\u200e22.1 x 22.1 x 22.1 cm; 300 Grams', 'Date First Available\u200f': '\u200e18 January 2018', 'Manufacturer\u200f': "\u200eL'OREAL India Pvt.Ltd.", 'ASIN\u200f': '\u200eB06Y3WVH2X', 'Item model number\u200f': '\u200eA-OX Vitamino Color', 'Country of Origin\u200f': '\u200eIndia', 'Item Weight\u200f': '\u200e300 g', 'Item Dimensions LxWxH\u200f': '\u200e22.1 x 22.1 x 22.1 Centimeters', 'Net Qu
# https://www.amazon.in/Herbal-Essences-bio-Morocco-Shampoo/dp/B07PB4G6RG/ref=sr_1_25?dchild=1&keywords=shampoo&qid=1622109910&sr=8-25
# {'Url': 'https://www.amazon.in/Herbal-Essences-bio-Morocco-Shampoo/dp/B07PB4G6RG/ref=sr_1_25?dchild=1&keywords=shampoo&qid=1622109910&sr=8-25', 'product Title': 'Herbal Essences Argan Oil of Morocco SHAMPOO- For Hair Repair and No Frizz- No Paraben No Colorants 400 ML', 'brand': 'NA', 'Products price': '420.00', 'Offer_Count': '4', 'StrikeThrough_Products_price': '600.0', 'Fullfilled': 'Fulfilled', 'Overall rating': '4.2 out of 5 stars', 'Total reviews': '4066 ratings', 'Availability': 'NA', 'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'], 'icons': ['Pay on Delivery', 'Not Returnable', 'Amazon Delivered', 'No-Contact Delivery'], 'Product_Details': {'Product Dimensions\u200f': '\u200e7.5 x 4.5 x 20.4 cm; 472 Grams', 'Date First Available\u200f': '\u200e27 February 2019', 'Manufacturer\u200f': '\u200eProcter & Gamble, Procter & Gamble Manufacturing (Thailand) Ltd., 112 Moo 5, Bangsamark, Bangpakong, Chachoengsao 24180 Thailand. 022-24942113', 'ASIN\u200f': '\u200eB07PB4G6RG', 'Item part number\u200f': '\u200e82297298-1', 'Country of Origin\u200f': '\u200eThailand', 'Packer\u200f': '\u200eProcter & Gamble Home Products Private Ltd, Plot No.1, Indl Area, Villate Katha, Baddi, Dist Solan, HP-173205 Comments/Complaints, call CONSUMER RELATIONS on 022-24942113', 'Importer\u200f': '\u200eProcter & Gamble Hygiene and Health Care Limited, P&G Plaza, Cardinal Gracias Road, Chakala, Andheri (E), Mumbai – 400099. Comments/Complaints, call CONSUMER RELATIONS on 022-24942113', 'Item Weight\u200f': '\u200e472 g', 'Item Dimensions LxWxH\u200f': '\u200e7.5 x 4.5 x 20.4 Centimeters', 'Net Quantity\u200f': '\u200e400.0 millilitre', 'Included Components\u200f': '\u200eShampoo', 'Generic Name\u200f': '\u200eBio Renew Argan Oil Of Morocco Shampoo', 'Best Sellers Rank': '#223 in Beauty (See Top 100 in Beauty) #34 in Shampoos (Beauty)'}, 'misc_info': 'Important informationIngredients:essential antioxidants, aloe and sea kelp, ARGAN OILDirections:apply shamppo generously to wet hair, massage into a creamy lather and then rinse', 'bought_together': ['Herbal Essences Argan Oil of Morocco SHAMPOO- For Hair Repair and No Frizz- No Paraben, No Colorants, 400 ML', 'Herbal Essences Argan Oil of Morocco CONDITIONER- For Hair Repair and No Frizz- No Paraben, No Colorants, 400 ML', 'Herbal Essences White Strawberry & Sweet Mint SHAMPOO- For Cleansing and Volume - No Paraben, No Colorants, 400 ML'], 'subscription_discount': '5%', 'variations': ['Morocco Shampoo + Coconut Milk Conditioner', 'Shampoo', 'Shampoo + Conditioner', 'Shampoo + Tea Shampoo']}
# --------------------------------------------------
# https://www.amazon.in/Kesh-King-Medicine-Hairfall-Shampoo/dp/B07F7DRX6J/ref=sr_1_26?dchild=1&keywords=shampoo&qid=1622109910&sr=8-26
# {'Url': 'https://www.amazon.in/Kesh-King-Medicine-Hairfall-Shampoo/dp/B07F7DRX6J/ref=sr_1_26?dchild=1&keywords=shampoo&qid=1622109910&sr=8-26', 'product Title': 'Kesh King Anti Hairfall Shampoo with aloe and 21 herbs 340ml', 'brand': 'Kesh King', 'Products price': '157.00', 'Offer_Count': '4', 'StrikeThrough_Products_price': '196.0', 'Fullfilled': 'Fulfilled', 'Overall rating': '4.2 out of 5 stars', 'Total reviews': '6501 ratings', 'Availability': 'NA', 'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'], 'icons': ['Not Returnable', 'Amazon Delivered', 'No-Contact Delivery'], 'Product_Details': {'Is Discontinued By Manufacturer\u200f': '\u200eNo', 'Product Dimensions\u200f': '\u200e4.4 x 7.8 x 22.2 cm; 309 Grams', 'Date First Available\u200f': '\u200e3 July 2018', 'Manufacturer\u200f': '\u200eEmami Limited', 'ASIN\u200f': '\u200eB07F7DRX6J', 'Item model number\u200f': '\u200eKM623', 'Country of Origin\u200f': '\u200eIndia', 'Item Weight\u200f': '\u200e309 g', 'Item Dimensions LxWxH\u200f': '\u200e44 x 78 x 222 Millimeters', 'Net Quantity\u200f': '\u200e340.0 millilitre', 'Included Components\u200f': '\u200e1U Hair Shampoo', 'Generic Name\u200f': '\u200eHair Shampoo', 'Best Sellers Rank': '#142 in Beauty (See Top 100 in Beauty) #19 in Shampoos (Beauty)'}, 'misc_info': 'Important informationIngredients:Bhringaraja (Eclipta alba),Jatamansi (Nardostachya jatamansi),Musta (Cyperus rotundus),Brahmi (Bacopa monnieri),Amalaki (Emblica officinalis) (Emblica officinalis),Nimba (Azadirachta indica),Mandukparni (Centella asiatica),,Methi (Trigonella foenum-graecum),Manjistha (Rubia cordifolia),Lodhra (Symplocos racemosa),Mehendi (Lawsonia inermis),Karanja (Pongamia pinnata),Tulasi (Ocimum sanctum),Kola (Zizyphus mauritiana),Goksura(Tribulus terrestris), Bibhitaka(Terminalia belerica),Haritaki (Terminalia chebula),Nagkesara (Mesua ferrea),Shikakai (Acacia concinna),Aloe Vera(Aloe Barbadensis),Rosemary (Rosmarinus officinalis)Directions:Apply onto wet scalp/hair gently and rinse off thoroughly after 3-4 minutes. Use thrice a week for 4 weeks followed by twice a week as maintenance therapy or as directed by a physician.', 'bought_together': ['Kesh King Anti Hairfall Shampoo with aloe and 21 herbs, 340ml', 'Kesh King Ayurvedic Anti Hairfall Hair Oil, 300ml', 'Kesh King Ayurvedic Scalp and Hair Oil, 100ml'], 'subscription_discount': '5%', 'variations': ['Anti Hairfall Shampoo', 'Anti Hairfall Shampoo + Shampoo (200ml+600ml)', 'Anti Hairfall Shampoo + Shampoo (340ml+600ml)']}
# --------------------------------------------------
# https://www.amazon.in/Indulekha-Bringha-Cleanser-Shampoo-340ml/dp/B07MZJ62FL/ref=sr_1_27?dchild=1&keywords=shampoo&qid=1622109910&sr=8-27
Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'], 'icons': ['Not Returnable'], 'Product_Details': {'Product Dimensions\u200f': '\u200e6 x 3 x 15 cm; 1 Grams', 'Date First Available\u200f': '\u200e13 June 2019', 'Manufacturer\u200f': '\u200eDabur India Limited', 'ASIN\u200f': '\u200eB07T4KFRT3', 'Item part number\u200f': '\u200e8901207025563_Fba', 'Country of Origin\u200f': '\u200eIndia', 'Item Weight\u200f': '\u200e1 g', 'Item Dimensions LxWxH\u200f': '\u200e6 x 3 x 15 Centimeters', 'Net Quantity\u200f': '\u200e650.0 millilitre', 'Included Components\u200f': '\u200e1 Shampoo', 'Generic Name\u200f': '\u200eAlmond Shampoo', 'Best Sellers Rank': '#7,320 in Beauty (See Top 100 in Beauty) #641 in Shampoos (Beauty)'}, 'misc_info': 'NA', 'bought_together': [], 'subscription_discount': 'NA', 'variations': []}
# --------------------------------------------------
# https://www.amazon.in/LOrealProfessionnel-Serie-Expert-OX-Shampoo300ml/dp/B06Y3WVH2X/ref=sr_1_73?dchild=1&keywords=shampoo&qid=1622109983&sr=8-73
# {'Url': 'https://www.amazon.in/LOrealProfessionnel-Serie-Expert-OX-Shampoo300ml/dp/B06Y3WVH2X/ref=sr_1_73?dchild=1&keywords=shampoo&qid=1622109983&sr=8-73', 'product Title': "L'Oréal Professionnel Serie Expert Vitamino Shampoo | For coloured hair |Protects hair colour from fading & adds shine |With Antioxidant properties", 'brand': "L'Oréal Professionnel", 'Products price': '665.00', 'Offer_Count': 'NA', 'StrikeThrough_Products_price': 'NA', 'Fullfilled': 'NA', 'Overall rating': '4.4 out of 5 stars', 'Total reviews': '818 ratings', 'Availability': 'NA', 'Category Tree': [], 'icons': ['Pay on Delivery', 'Not Returnable', 'Amazon Delivered', 'No-Contact Delivery'], 'Product_Details': {'Batteries\u200f': '\u200e1 A batteries required.', 'Is Discontinued By Manufacturer\u200f': '\u200eNo', 'Product Dimensions\u200f': '\u200e22.1 x 22.1 x 22.1 cm; 300 Grams', 'Date First Available\u200f': '\u200e18 January 2018', 'Manufacturer\u200f': "\u200eL'OREAL India Pvt.Ltd.", 'ASIN\u200f': '\u200eB06Y3WVH2X', 'Item model number\u200f': '\u200eA-OX Vitamino Color', 'Country of Origin\u200f': '\u200eIndia', 'Item Weight\u200f': '\u200e300 g', 'Item Dimensions LxWxH\u200f': '\u200e22.1 x 22.1 x 22.1 Centimeters', 'Net Quantity\u200f': '\u200e300.0 millilitre', 'Included Components\u200f': '\u200e1-Shampoo', 'Generic Name\u200f': '\u200eShampoo', 'Best Sellers Rank': '#610 in Beauty (See Top 100 in Beauty) #7 in Hair Masks & Packs #78 in Shampoos (Beauty)'}, 'misc_info': 'NA', 'bought_together': ["L'Oréal Professionnel Serie Exp
# %%
complete_data
# Out:
# [{'Availability': 'NA',
#   'Category Tree': [],
#   'Fullfilled': 'NA',
#   'Offer_Count': 'NA',
#   'Overall rating': '4.5 out of 5 stars',
#   'Product_Details': {'ASIN\u200f': '\u200eB00E6KILTC',
#    'Best Sellers Rank': '#30,285 in Beauty (See Top 100 in Beauty) #1,946 in Shampoos (Beauty)',
#    'Country of Origin\u200f': '\u200eFrance',
#    'Date First Available\u200f': '\u200e22 August 2014',
#    'Is Discontinued By Manufacturer\u200f': '\u200eNo',
#    'Item Dimensions LxWxH\u200f': '\u200e5.9 x 5.9 x 16.7 Centimeters',
#    'Item Weight\u200f': '\u200e300 g',
#    'Item model number\u200f': '\u200e17SH300G18',
#    'Manufacturer\u200f': "\u200eL'Occitane",
#    'Net Quantity\u200f': '\u200e300.0 millilitre',
#    'Product Dimensions\u200f': '\u200e5.89 x 5.89 x 16.69 cm; 300 Grams'},
#   'Products price': '1950.00',
#   'StrikeThrough_Products_price': 'NA',
#   'Total reviews': '737 ratings',
#   'Url': 'https://www.amazon.in/LOccitane-Aromachologie-Repairing-Shampoo-300ml/dp/B00E6KILTC/ref=sxin_10?asc_contentid=amzn1.osa.616a1218-209a-4c6e-b84c-511fbc004b38.A21TJRUUN4KGV.en_IN&asc_contenttype=article&ascsubtag=amzn1.osa.616a1218-209a-4c6e-b84c-511fbc004b38.A21TJRUUN4KGV.en_IN&creativeASIN=B00E6KILTC&cv_ct_cx=shampoo&cv_ct_id=amzn1.osa.616a1218-209a-4c6e-b84c-511fbc004b38.A21TJRUUN4KGV.en_IN&cv_ct_pg=search&cv_ct_we=asin&cv_ct_wn=osp-single-source-pecos-desktop&dchild=1&keywords=shampoo&linkCode=oas&pd_rd_i=B00E6KILTC&pd_rd_r=2dc6b676-5de4-46d9-965d-d5f5ec455d15&pd_rd_w=t9M3P&pd_rd_wg=av0AI&pf_rd_p=6567d3a4-28dd-430b-a035-b0af9623dfa4&pf_rd_r=1SK879FYV6GQC83CRS5N&qid=1622109910&sr=1-4-c84eb971-91f2-4a4d-acce-811265c24254&tag=timeszoom-21',
#   'bought_together': [],
#   'brand': "L'OCCITANE",
#   'icons': ['Pay on Delivery',
#    'Not Returnable',
#    'Amazon Delivered',
#    'No-Contact Delivery'],
#   'misc_info': 'NA',
#   'product Title': "L'Occitane Damaged Hair Intensive Repairing Shampoo 300ml",
#   'subscription_discount': 'NA',
#   'variations': []},
#  {'Availability': 'NA',
#   'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'],
#   'Fullfilled': 'Fulfilled',
#   'Offer_Count': '4',
#   'Overall rating': '4.3 out of 5 stars',
#   'Product_Details': {'ASIN\u200f': '\u200eB08CSHBPD5',
#    'Best Sellers Rank': '#20 in Beauty (See Top 100 in Beauty) #4 in Shampoos (Beauty)',
#    'Country of Origin\u200f': '\u200eIndia',
#    'Date First Available\u200f': '\u200e10 July 2020',
#    'Generic Name\u200f': '\u200eTotal Repair 5 Shampoo',
#    'Item Dimensions LxWxH\u200f': '\u200e10.5 x 7.8 x 24.8 Centimeters',
#    'Item Weight\u200f': '\u200e1 kg 130 g',
#    'Item part number\u200f': '\u200eHESTR900-00',
#    'Manufacturer\u200f': "\u200eL'Oreal India Pvt. Ltd., Loreal India Pvt Ltd, Chakan, Pune - 410 501",
#    'Net Quantity\u200f': '\u200e1000.0 millilitre',
#    'Product Dimensions\u200f': '\u200e10.5 x 7.8 x 24.8 cm; 1.13 Kilograms'},
#   'Products price': '519.00',
#   'StrikeThrough_Products_price': '796.0',
#   'Total reviews': '9365 ratings',
#   'Url': 'https://www.amazon.in/LOreal-Paris-Total-Repair-Shampoo/dp/B08CSHBPD5/ref=sr_1_8?dchild=1&keywords=shampoo&qid=1622109910&sr=8-8',
#   'bought_together': ["L'Oreal Paris Total Repair 5 Shampoo, 1 Litre",
#    "L'Oreal Paris Total Repair 5 Conditioner, 192.5ml",
#    "L'Oreal Paris Total Repair 5 Serum, 80ml"],
#   'brand': "L'Oreal Paris",
#   'icons': ['Pay on Delivery',
#    'Not Returnable',
#    'Amazon Delivered',
#    'No-Contact Delivery'],
#   'misc_info': 'Important informationIngredients:AQUA / WATER, SODIUM LAURETH SULFATE, COCO-BETAINE, DIMETHICONE, GLYCOL DISTEARATE, SODIUM CHLORIDE, GUAR HYDROXYPROPYLTRIMONIUM CHLORIDE, QUATERNIUM-33, SODIUM BENZOATE, HYDROXYPROPYLTRIMONIUM HYDROLYZED WHEAT PROTEIN, SODIUM HYDROXIDE, PPG-5-CETETH-20, ARGININE, BEHENTRIMONIUM METHOSULFATE, SALICYLIC ACID, POLYQUATERNIUM-7, LIMONENE, LINALOOL, BENZYL SALICYLATE, BENZYL ALCOHOL, 2-OLEAMIDO-1, 3-OCTADECANEDIOL, CARBOMER, SERINE, BUTYLPHENYL METHYLPROPIONAL, CETYL ALCOHOL, CITRIC ACID, GLUTAMIC ACID, HEXYL CINNAMAL, GLYCERYL LINOLEATE, GLYCERYL OLEATE, GLYCERYL LINOLENATE, PARFUM / FRAGRANCE, (F.I.L. C170134/1)',
#   'product Title': "L'Oreal Paris Total Repair 5 Shampoo 1 Litre",
#   'subscription_discount': '5%',
#   'variations': ['Shampoo',
#    'Shampoo & Conditioner',
#    'Shampoo + Conditioner',
#    'Shampoo + Conditioner + Total repair']},
#  {'Availability': 'NA',
#   'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'],
#   'Fullfilled': 'Fulfilled',
#   'Offer_Count': '4',
#   'Overall rating': '4.2 out of 5 stars',
#   'Product_Details': {'ASIN\u200f': '\u200eB08T2Y2Q4T',
#    'Best Sellers Rank': '#79 in Beauty (See Top 100 in Beauty) #11 in Shampoos (Beauty)',
#    'Country of Origin\u200f': '\u200eIndia',
#    'Date First Available\u200f': '\u200e14 January 2021',
#    'Generic Name\u200f': '\u200eDream Lengths Shampoo',
#    'Importer\u200f': '\u200eLoreal Paris India Pvt. Ltd.',
#    'Included Components\u200f': '\u200eShampoo',
#    'Item Dimensions LxWxH\u200f': '\u200e6.8 x 3.3 x 18 Centimeters',
#    'Item Weight\u200f': '\u200e130 g',
#    'Item part number\u200f': '\u200eHESDL175-00',
#    'Manufacturer\u200f': "\u200eL'Oréal Paris India Pvt Ltd., Loreal India Pvt Ltd, Chakan, Pune - 410501",
#    'Net Quantity\u200f': '\u200e192.5 millilitre',
#    'Packer\u200f': '\u200eLoreal India Pvt Ltd, Chakan, Pune - 410501',
#    'Product Dimensions\u200f': '\u200e6.8 x 3.3 x 18 cm; 130 Grams'},
#   'Products price': '141.00',
#   'StrikeThrough_Products_price': '149.0',
#   'Total reviews': '2444 ratings',
#   'Url': 'https://www.amazon.in/LOreal-Paris-Dream-Lengths-Shampoo/dp/B08T2Y2Q4T/ref=sr_1_9?dchild=1&keywords=shampoo&qid=1622109910&sr=8-9',
#   'bought_together': ["L'Oreal Paris Dream Lengths Shampoo, 192.5 ml",
#    "L'Oreal Paris Dream Lengths Conditioner, 192.5 ml",
#    "L'Oréal Paris Dream Lengths No Haircut Cream Leave-In Conditioner, 200ml"],
#   'brand': "L'Oreal Paris",
#   'icons': ['Not Returnable', 'Amazon Delivered', 'No-Contact Delivery'],
#   'misc_info': 'NA',
#   'product Title': "L'Oreal Paris Dream Lengths Shampoo 192.5 ml",
#   'subscription_discount': 'NA',
#   'variations': []},
#  {'Availability': 'NA',
#   'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'],
#   'Fullfilled': 'Fulfilled',
#   'Offer_Count': '4',
#   'Overall rating': '4.3 out of 5 stars',
#   'Product_Details': {'ASIN\u200f': '\u200eB074VG8ZH8',
#    'Best Sellers Rank': '#454 in Beauty (See Top 100 in Beauty) #61 in Shampoos (Beauty)',
#    'Country of Origin\u200f': '\u200eIndia',
#    'Date First Available\u200f': '\u200e16 August 2017',
#    'Generic Name\u200f': '\u200eShampoo',
#    'Included Components\u200f': '\u200eShampoo',
#    'Is Discontinued By Manufacturer\u200f': '\u200eNo',
#    'Item Dimensions LxWxH\u200f': '\u200e10 x 10 x 25 Centimeters',
#    'Item Weight\u200f': '\u200e720 g',
#    'Item part number\u200f': '\u200eHESEC640-00',
#    'Manufacturer\u200f': '\u200ePritam International Pvt Ltd.',
#    'Net Quantity\u200f': '\u200e704.0 millilitre',
#    'Product Dimensions\u200f': '\u200e10 x 10 x 25 cm; 720 Grams'},
#   'Products price': '432.00',
#   'StrikeThrough_Products_price': '450.0',
#   'Total reviews': '1253 ratings',
#   'Url': 'https://www.amazon.in/LOreal-Paris-Extraordinary-Shampoo-640ml/dp/B074VG8ZH8/ref=sr_1_10?dchild=1&keywords=shampoo&qid=1622109910&sr=8-10',
#   'bought_together': ["L'Oreal Paris Extraordinary Clay Shampoo, 704 ml (640 ml + 64 ml)",
#    "L'Oreal Paris Extraordinary Clay Conditioner, 175ml (With 10% Extra)",
#    "L'Oreal Paris Rapid Reviver Extraordinary Clay Deep Conditioner, 180ml"],
#   'brand': 'NA',
#   'icons': ['Pay on Delivery',
#    'Not Returnable',
#    'Amazon Delivered',
#    'No-Contact Delivery'],
#   'misc_info': 'Important informationIngredients:AQUA / WATER / EAU,SODIUM LAURETH SULFATE,COCO-BETAINE,GLYCOL DISTEARATE,SODIUM CHLORIDE ,PPG-5-CETETH-20, PARFUM / FRAGRANCE SODIUM BENZOATE, OCTYLDODECANOL, SALICYLIC ACID, GUAR HYDROXYPROPYLTRIMONIUM CHLORIDE, CARBOMER, LINALOOL, HEXYL CINNAMAL, BENZYL ALCOHOL, BENZYL SALICYLATE, CITRONELLOL, ARGILLA / MAGNESIUM, ALUMINUM SILICATE, KAOLIN, MONTMORILLONITE, GERANIOL, ALPHA-ISOMETHYL IONONE, FUMARIC ACID, SODIUM HYALURONATE, CI 42090 / BLUE 1, SODIUM HYDROXIDE, CITRIC ACID',
#   'product Title': "L'Oreal Paris Extraordinary Clay Shampoo 704 ml (640 ml + 64 ml)",
#   'subscription_discount': '5%',
#   'variations': ['Extraordinary Clay Shampoo + Condtioner',
#    'Extraordinary Clay Shampoo',
#    'Extraordinary Clay Shampoo + Clay Conditioner',
#    'Extraordinary Clay Shampoo + Conditioner']},
#  {'Availability': 'NA',
#   'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'],
#   'Fullfilled': 'Fulfilled',
#   'Offer_Count': '4',
#   'Overall rating': '4.3 out of 5 stars',
#   'Product_Details': {'ASIN\u200f': '\u200eB07F2QCLP2',
#    'Best Sellers Rank': '#300 in Beauty (See Top 100 in Beauty) #47 in Shampoos (Beauty)',
#    'Country of Origin\u200f': '\u200eIndia',
#    'Date First Available\u200f': '\u200e27 June 2018',
#    'Item Dimensions LxWxH\u200f': '\u200e1 x 92 x 259 Millimeters',
#    'Item Weight\u200f': '\u200e580 g',
#    'Item part number\u200f': '\u200e11616',
#    'Manufacturer\u200f': '\u200eHUL',
#    'Net Quantity\u200f': '\u200e580.0 millilitre',
#    'Product Dimensions\u200f': '\u200e0.1 x 9.2 x 25.9 cm; 580 Grams'},
#   'Products price': '364.80',
#   'StrikeThrough_Products_price': '425.0',
#   'Total reviews': '6544 ratings',
#   'Url': 'https://www.amazon.in/TRESemme-Hair-Defense-Shampoo-580ml/dp/B07F2QCLP2/ref=sr_1_11?dchild=1&keywords=shampoo&qid=1622109910&sr=8-11',
#   'bought_together': ['Tresemme Hair Fall Defence Shampoo, For Strong Hair, With Keratin Protein, Prevent Hair Fall due to Breakage, 580 ml',
#    'Tresemme Hair Fall Defense Conditioner, With Keratin Protein, Prevents Hair Fall due to Breakage, Gives Longer & Stronger Hair, 190 ml',
#    'Tresemme Keratin Smooth Conditioner, With Keratin And Argan Oil For Straighter, Smoother And Shinier Hair, 190 ml'],
#   'brand': 'TRESemme',
#   'icons': ['Pay on Delivery',
#    'Not Returnable',
#    'Amazon Delivered',
#    'No-Contact Delivery'],
#   'misc_info': 'Important informationSafety Information:Avoid contact with eyes. In case of contact rinse thoroughly with waterIndications:• Apply to your wet hair and gently massage and work it into a lather. • After the application rinse thoroughly. • After rinsing shampoo, use the TRESemme Conditioner.Directions:Store in a cool and dry place.',
#   'product Title': 'Tresemme Hair Fall Defence Shampoo For Strong Hair With Keratin Protein Prevent Hair Fall due to Breakage 580 ml',
#   'subscription_discount': 'NA',
#   'variations': ['Shampoo',
#    'Shampoo 580ml + Conditioner 190ml',
#    'Hairfall Defense Shampoo + Shampoo, 340ml',
#    'Hairfall Defense Shampoo + Shampoo, 580ml',
#    'Hairfall Defense Shampoo + Shampoo, 650ml',
#    'Hairfall Defense Shampoo + Shine Shampoo',
#    'Shampoo + Conditioner',
#    'Shampoo, 580ml + Body Lotion, 200ml',
#    'Shampoo, 580ml + Daily Shine Conditioner',
#    'Shampoo, 580ml + Hair Therapy Conditioner']},
#  {'Availability': 'NA',
#   'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'],
#   'Fullfilled': 'Fulfilled',
#   'Offer_Count': '4',
#   'Overall rating': '4.4 out of 5 stars',
#   'Product_Details': {'ASIN\u200f': '\u200eB07L3YNL2V',
#    'Best Sellers Rank': '#176 in Beauty (See Top 100 in Beauty) #24 in Shampoos (Beauty)',
#    'Country of Origin\u200f': '\u200eIndia',
#    'Date First Available\u200f': '\u200e4 December 2018',
#    'Generic Name\u200f': '\u200eHair Fall Defence Shampoo',
#    'Item Dimensions LxWxH\u200f': '\u200e22.9 x 10.2 x 6.4 Centimeters',
#    'Item Weight\u200f': '\u200e1 kg',
#    'Item part number\u200f': '\u200e26119',
#    'Manufacturer\u200f': '\u200eHUL',
#    'Net Quantity\u200f': '\u200e1000.0 millilitre',
#    'Product Dimensions\u200f': '\u200e22.9 x 10.2 x 6.4 cm; 1 Kilograms'},
#   'Products price': '525.00',
#   'StrikeThrough_Products_price': '648.0',
#   'Total reviews': '3940 ratings',
#   'Url': 'https://www.amazon.in/TRESemme-Hair-Defence-Shampoo-1000ml/dp/B07L3YNL2V/ref=sr_1_12?dchild=1&keywords=shampoo&qid=1622109910&sr=8-12',
#   'bought_together': ['Tresemme Hair Fall Defence Shampoo, For Strong Hair, With Keratin Protein, Prevents Hair Fall due to Breakage, 1 Ltr',
#    'Tresemme Hair Fall Defense Conditioner, With Keratin Protein, Prevents Hair Fall due to Breakage, Gives Longer & Stronger Hair, 190 ml',
#    'Tresemme Keratin Smooth Conditioner, With Keratin And Argan Oil For Straighter, Smoother And Shinier Hair, 190 ml'],
#   'brand': 'NA',
#   'icons': ['Pay on Delivery',
#    'Not Returnable',
#    'Amazon Delivered',
#    'No-Contact Delivery'],
#   'misc_info': 'Important informationSafety Information:Avoid contact with eyes. In case of contact rinse thoroughly with waterIndications:Apply to your wet hair and gently massage and work it into a lather. • After the application rinse thoroughly. • After rinsing shampoo, use the TRESemme Conditioner.Directions:Store in a cool and dry place.',
#   'product Title': 'Tresemme Hair Fall Defence Shampoo For Strong Hair With Keratin Protein Prevents Hair Fall due to Breakage 1 Ltr',
#   'subscription_discount': '5%',
#   'variations': []},
#  {'Availability': 'In stock on June 17 2021.',
#   'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'],
#   'Fullfilled': 'Fulfilled',
#   'Offer_Count': '4',
#   'Overall rating': '4.4 out of 5 stars',
#   'Product_Details': {'ASIN\u200f': '\u200eB07H9T25WH',
#    'Best Sellers Rank': '#47 in Beauty (See Top 100 in Beauty) #6 in Shampoos (Beauty)',
#    'Country of Origin\u200f': '\u200eIndia',
#    'Date First Available\u200f': '\u200e13 September 2018',
#    'Item Dimensions LxWxH\u200f': '\u200e7.2 x 9.4 x 23 Centimeters',
#    'Item Weight\u200f': '\u200e1 kg',
#    'Item part number\u200f': '\u200e12996',
#    'Manufacturer\u200f': '\u200eHUL',
#    'Net Quantity\u200f': '\u200e1000.0 millilitre',
#    'Product Dimensions\u200f': '\u200e7.2 x 9.4 x 23 cm; 1 Kilograms'},
#   'Products price': '475.80',
#   'StrikeThrough_Products_price': '580.0',
#   'Total reviews': '10128 ratings',
#   'Url': 'https://www.amazon.in/Dove-Hair-Fall-Rescue-Shampoo/dp/B07H9T25WH/ref=sr_1_13?dchild=1&keywords=shampoo&qid=1622109910&sr=8-13',
#   'bought_together': ['Dove Hair Fall Rescue Shampoo For Weak Hair Prone To Hairfall, Deeply Nourishes From Roots Up And Reduces Hair Fall, 1 Ltr',
#    'Himalaya Purifying Neem Face Wash, 400 ml',
#    'Dove Deeply Nourishing Body Wash, With Exfoliating Beads For Softer, Smoother Skin, 800 ml'],
#   'brand': 'Dove',
#   'icons': ['Pay on Delivery',
#    'Not Returnable',
#    'Amazon Delivered',
#    'No-Contact Delivery'],
#   'misc_info': 'Important informationDirections:Store in cool & dry place away from sunlight',
#   'product Title': 'Dove Hair Fall Rescue Shampoo For Weak Hair Prone To Hairfall Deeply Nourishes From Roots Up And Reduces Hair Fall 1 Ltr',
#   'subscription_discount': '5%',
#   'variations': []},
#  {'Availability': 'NA',
#   'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'],
#   'Fullfilled': 'Fulfilled',
#   'Offer_Count': '4',
#   'Overall rating': '4.1 out of 5 stars',
#   'Product_Details': {'ASIN\u200f': '\u200eB07YWMQRNJ',
#    'Best Sellers Rank': '#192 in Beauty (See Top 100 in Beauty) #26 in Shampoos (Beauty)',
#    'Country of Origin\u200f': '\u200eIndia',
#    'Date First Available\u200f': '\u200e9 October 2019',
#    'Generic Name\u200f': '\u200eKelp Protein Shampoo For Falling Hair',
#    'Importer\u200f': '\u200eBio Veda Action Research Company, Khasra No 439/42 Mauja Rampur Ghat, Tehsil-Paonta Sahib, Dist-Sirmour, Pin 173025 (H.P), India',
#    'Is Discontinued By Manufacturer\u200f': '\u200eNo',
#    'Item Dimensions LxWxH\u200f': '\u200e19.6 x 7.9 x 4.6 Centimeters',
#    'Item Weight\u200f': '\u200e320 g',
#    'Item part number\u200f': '\u200eNEWRETWH0058',
#    'Manufacturer\u200f': '\u200eBio Veda Action Research Company',
#    'Net Quantity\u200f': '\u200e340.0 millilitre',
#    'Product Dimensions\u200f': '\u200e19.6 x 7.9 x 4.6 cm; 320 Grams'},
#   'Products price': '209.00',
#   'StrikeThrough_Products_price': '299.0',
#   'Total reviews': '7945 ratings',
#   'Url': 'https://www.amazon.in/Biotique-Protein-Intensive-Regrowth-Treatment/dp/B07YWMQRNJ/ref=sr_1_14?dchild=1&keywords=shampoo&qid=1622109910&sr=8-14',
#   'bought_together': ['Biotique Bio Kelp Protein Shampoo for Falling Hair Intensive Hair Regrowth Treatment, 340ml',
#    'Biotique Bio Mountain Ebony Vitalizing Serum For Falling Hair Intensive Hair Growth Treatment, 120ML',
#    'Biotique Bio Bhringraj Therapeutic Hair Oil for Falling Hair Intensive Hair Regrowth Treatment, 120ml'],
#   'brand': 'Biotique',
#   'icons': ['Not Returnable', 'Amazon Delivered', 'No-Contact Delivery'],
#   'misc_info': 'NA',
#   'product Title': 'Biotique Bio Kelp Protein Shampoo for Falling Hair Intensive Hair Regrowth Treatment 340ml',
#   'subscription_discount': '5%',
#   'variations': []},
#  {'Availability': 'NA',
#   'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'],
#   'Fullfilled': 'Fulfilled',
#   'Offer_Count': '4',
#   'Overall rating': '4.2 out of 5 stars',
#   'Product_Details': {'ASIN\u200f': '\u200eB01M0PCSDR',
#    'Best Sellers Rank': '#202 in Beauty (See Top 100 in Beauty) #31 in Shampoos (Beauty)',
#    'Country of Origin\u200f': '\u200eIndia',
#    'Date First Available\u200f': '\u200e6 October 2016',
#    'Generic Name\u200f': '\u200eShampoo',
#    'Included Components\u200f': '\u200eShampoo',
#    'Is Discontinued By Manufacturer\u200f': '\u200eNo',
#    'Item Dimensions LxWxH\u200f': '\u200e9.4 x 6.3 x 24.5 Centimeters',
#    'Item Weight\u200f': '\u200e883 g',
#    'Item part number\u200f': '\u200eNAH0800R',
#    'Manufacturer\u200f': '\u200eCavinKare Pvt. Ltd, CavinKare Pvt. Ltd., Cavinville, No. 12, Cenotaph Road, Chennai - 600 018, 1800 419 0671',
#    'Net Quantity\u200f': '\u200e800.0 millilitre',
#    'Packer\u200f': '\u200eCavinKare Pvt. Ltd., Cavinville, No. 12, Cenotaph Road, Chennai - 600 018, 1800 419 0671',
#    'Product Dimensions\u200f': '\u200e9.4 x 6.3 x 24.5 cm; 883 Grams'},
#   'Products price': '214.00',
#   'StrikeThrough_Products_price': '305.0',
#   'Total reviews': '2937 ratings',
#   'Url': 'https://www.amazon.in/Nyle-Anti-Hairfall-Shampoo-800ml/dp/B01M0PCSDR/ref=sr_1_15?dchild=1&keywords=shampoo&qid=1622109910&sr=8-15',
#   'bought_together': [],
#   'brand': 'NA',
#   'icons': ['Not Returnable', 'Amazon Delivered', 'No-Contact Delivery'],
#   'misc_info': 'NA',
#   'product Title': 'Nyle Anti-Hairfall Shampoo 800ml',
#   'subscription_discount': '5%',
#   'variations': ['Anti-Hairfall',
#    'Anti-Hairfall + Damage Repair',
#    'Anti-Hairfall + Damage Repair + Dryness Hydration',
#    'Anti-Hairfall + Dryness Hydration',
#    'Anti-Hairfall + Pollution Shield',
#    'Anti-Hairfall + Volume Enhance']},
#  {'Availability': 'NA',
#   'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'],
#   'Fullfilled': 'Fulfilled',
#   'Offer_Count': '4',
#   'Overall rating': '4.0 out of 5 stars',
#   'Product_Details': {'ASIN\u200f': '\u200eB01N3YESMI',
#    'Best Sellers Rank': '#167 in Beauty (See Top 100 in Beauty) #22 in Shampoos (Beauty)',
#    'Country of Origin\u200f': '\u200eIndia',
#    'Date First Available\u200f': '\u200e18 October 2013',
#    'Generic Name\u200f': '\u200eAyurvedic Amla and Bhringraj Hair Cleanser (Shampoo) Sls and Paraben Free',
#    'Included Components\u200f': '\u200eLabel, shrink wrap, carton',
#    'Is Discontinued By Manufacturer\u200f': '\u200eNo',
#    'Item Dimensions LxWxH\u200f': '\u200e15 x 4.2 x 4.2 Centimeters',
#    'Item Weight\u200f': '\u200e211 g',
#    'Manufacturer\u200f': '\u200eKhadi Naturals',
#    'Net Quantity\u200f': '\u200e210.0 millilitre',
#    'Product Dimensions\u200f': '\u200e15 x 4.2 x 4.2 cm; 211 Grams'},
#   'Products price': '160.00',
#   'StrikeThrough_Products_price': '235.0',
#   'Total reviews': '3130 ratings',
#   'Url': 'https://www.amazon.in/Khadi-Natural-Bhringraj-Shampoo-Cleanser/dp/B01N3YESMI/ref=sr_1_16?dchild=1&keywords=shampoo&qid=1622109910&sr=8-16',
#   'bought_together': ['KHADI NATURAL Ayurvedic Amla and Bhringraj Hair Cleanser(Shampoo), SLS and Paraben Free, 210ml',
#    'Khadi NaturalÂ\xa0Shikakai and Honey Herbal Hair Conditioner, SLS and Paraben Free, 210ml',
#    'KHADI NATURAL Neem and Aloevera Herbal Hair Cleanser/Shampoo, SLS and Paraben Free, 210ml'],
#   'brand': 'KHADI NATURAL',
#   'icons': ['Not Returnable', 'Amazon Delivered', 'No-Contact Delivery'],
#   'misc_info': 'Important informationLegal Disclaimer:100% KHADI NATURAL PRODUCT ORIGINAL PACKING MFG: JUNE 2016 EXP : 2 YEARS',
#   'product Title': 'KHADI NATURAL Ayurvedic Amla and Bhringraj Hair Cleanser(Shampoo) SLS and Paraben Free 210ml',
#   'subscription_discount': 'NA',
#   'variations': ['Hair oil', 'Hair oil + Hair cleanser']},
#  {'Availability': 'NA',
#   'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'],
#   'Fullfilled': 'Fulfilled',
#   'Offer_Count': '4',
#   'Overall rating': '4.0 out of 5 stars',
#   'Product_Details': {'ASIN\u200f': '\u200eB08ZSFMGW1',
#    'Best Sellers Rank': '#194 in Beauty (See Top 100 in Beauty) #28 in Shampoos (Beauty)',
#    'Country of Origin\u200f': '\u200eIndia',
#    'Date First Available\u200f': '\u200e23 March 2021',
#    'Item Weight\u200f': '\u200e290 g',
#    'Item part number\u200f': '\u200eME_Ricewater_Shampoo250ml',
#    'Manufacturer\u200f': '\u200eMamaearth',
#    'Net Quantity\u200f': '\u200e1.00 count',
#    'Package Dimensions\u200f': '\u200e20.6 x 4.9 x 4.9 cm; 290 Grams'},
#   'Products price': '313.00',
#   'StrikeThrough_Products_price': '349.0',
#   'Total reviews': '565 ratings',
#   'Url': 'https://www.amazon.in/Mamaearth-Shampoo-Keratin-Damaged-Frizzy/dp/B08ZSFMGW1/ref=sr_1_17?dchild=1&keywords=shampoo&qid=1622109910&smid=A61C6NUFGVGS7&sr=8-17',
#   'bought_together': [],
#   'brand': 'Mamaearth',
#   'icons': ['Pay on Delivery',
#    'Not Returnable',
#    'Amazon Delivered',
#    'No-Contact Delivery'],
#   'misc_info': 'Important informationIngredients:Aqua, Cocamidopropyl Betaine, Caprylyl/Capryl Glucoside, Sodium Methyl Cocoyl Taurate, Glycerin, Sodium Lauroyl Sarcosinate, Cocamide MEA, Polyquaternium 7, Cetrimonium Chloride, Polyquaternium 10, Polyquaternium 73, Anhydrous Betaine, IFRA Certified Allergen Free Fragrance, Fermented Rice Water, Sodium Benzoate, Potassium Sorbate, D-Panthenol, Disodium EDTA, Cetyl Alcohol & Hydrolyzed KeratinDirections:1. Gently massage shampoo onto wet hair and scalp with fingertips. 2. Rinse thoroughly and follow it up with Mamaearth Rice Water Conditioner.',
#   'product Title': 'Mamaearth Rice Water Shampoo With Rice Water & Keratin For Damaged Dry and Frizzy Hair – 250ml',
#   'subscription_discount': 'NA',
#   'variations': []},
#  {'Availability': 'NA',
#   'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'],
#   'Fullfilled': 'Fulfilled',
#   'Offer_Count': '4',
#   'Overall rating': '4.3 out of 5 stars',
#   'Product_Details': {'ASIN\u200f': '\u200eB008KH6VP8',
#    'Best Sellers Rank': '#215 in Beauty (See Top 100 in Beauty) #32 in Shampoos (Beauty)',
#    'Country of Origin\u200f': '\u200eIndia',
#    'Date First Available\u200f': '\u200e16 October 2013',
#    'Generic Name\u200f': '\u200eShampoo',
#    'Included Components\u200f': '\u200eShampoo',
#    'Is Discontinued By Manufacturer\u200f': '\u200eNo',
#    'Item Dimensions LxWxH\u200f': '\u200e7.6 x 4.2 x 22 Centimeters',
#    'Item Weight\u200f': '\u200e340 g',
#    'Item model number\u200f': '\u200eShampoo_51',
#    'Manufacturer\u200f': '\u200ePritam International Pvt Ltd.',
#    'Net Quantity\u200f': '\u200e340.0 millilitre',
#    'Product Dimensions\u200f': '\u200e7.6 x 4.2 x 22 cm; 340 Grams'},
#   'Products price': '156.00',
#   'StrikeThrough_Products_price': '235.0',
#   'Total reviews': '3151 ratings',
#   'Url': 'https://www.amazon.in/Garnier-Fructis-Strong-Strengthening-Shampoo/dp/B008KH6VP8/ref=sr_1_18?dchild=1&keywords=shampoo&qid=1622109910&sr=8-18',
#   'bought_together': [],
#   'brand': 'Garnier',
#   'icons': ['Not Returnable', 'Amazon Delivered', 'No-Contact Delivery'],
#   'misc_info': 'NA',
#   'product Title': 'Garnier Fructis Long and Strong Strengthening Shampoo 340ml',
#   'subscription_discount': '5%',
#   'variations': []},
#  {'Availability': 'In stock on June 20 2021.',
#   'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'],
#   'Fullfilled': 'Fulfilled',
#   'Offer_Count': '4',
#   'Overall rating': '4.4 out of 5 stars',
#   'Product_Details': {'ASIN\u200f': '\u200eB07H9SV624',
#    'Best Sellers Rank': '#29 in Beauty (See Top 100 in Beauty) #5 in Shampoos (Beauty)',
#    'Country of Origin\u200f': '\u200eIndia',
#    'Date First Available\u200f': '\u200e13 September 2018',
#    'Item Dimensions LxWxH\u200f': '\u200e7.2 x 10.6 x 23.4 Centimeters',
#    'Item Weight\u200f': '\u200e1 kg 140 g',
#    'Item part number\u200f': '\u200e12995',
#    'Manufacturer\u200f': '\u200eHUL',
#    'Net Quantity\u200f': '\u200e1000.0 millilitre',
#    'Product Dimensions\u200f': '\u200e7.2 x 10.6 x 23.4 cm; 1.14 Kilograms'},
#   'Products price': '475.80',
#   'StrikeThrough_Products_price': '690.0',
#   'Total reviews': '13017 ratings',
#   'Url': 'https://www.amazon.in/Dove-Intense-Repair-Shampoo-1L/dp/B07H9SV624/ref=sr_1_19?dchild=1&keywords=shampoo&qid=1622109910&smid=AT95IG9ONZD7S&sr=8-19',
#   'bought_together': ['Dove Intense Repair Shampoo For Damaged Hair,Enriched with Fiber Actives, Repairs Hair Damage , Makes Hair Smooth And Strong,',
#    'Dove Intense Repair Conditioner For Damaged, Frizzy Hair, Deep Nourishment For Healthy, For Smooth, Frizz Protected Hair, 175',
#    'Dove Daily Shine Shampoo - For Dull And Frizzy Hair, Makes Hair Soft, Shiny And Smooth, For Daily Use, 340 ml'],
#   'brand': 'Dove',
#   'icons': ['Pay on Delivery',
#    'Not Returnable',
#    'Amazon Delivered',
#    'No-Contact Delivery'],
#   'misc_info': "Important informationDirections:Completely soak your hair and massage your shampoo gently over your scalp. Rinse it out well. Usually rinse and repeat? For daily shampooing the rinse and repeat rule isn't actually necessary (unless you've been trigger-happy with the hairspray), so just once will do",
#   'product Title': 'Dove Intense Repair Shampoo For Damaged HairEnriched with Fiber Actives Repairs Hair Damage  Makes Hair Smooth And Strong 1 Ltr',
#   'subscription_discount': '5%',
#   'variations': []},
#  {'Availability': 'NA',
#   'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'],
#   'Fullfilled': 'Fulfilled',
#   'Offer_Count': '4',
#   'Overall rating': '4.1 out of 5 stars',
#   'Product_Details': {'ASIN\u200f': '\u200eB08HSS5BY1',
#    'Best Sellers Rank': '#1,768 in Beauty (See Top 100 in Beauty) #199 in Shampoos (Beauty)',
#    'Country of Origin\u200f': '\u200eIndia',
#    'Date First Available\u200f': '\u200e10 September 2020',
#    'Generic Name\u200f': '\u200eAlmond & Honey Shampoo',
#    'Item Dimensions LxWxH\u200f': '\u200e6.2 x 4.4 x 21.5 Centimeters',
#    'Item Weight\u200f': '\u200e400 g',
#    'Item part number\u200f': '\u200e26338',
#    'Manufacturer\u200f': '\u200eYODEVA PLASTICS (P) LTD, MFG. BY YODEVA PLASTICS (P) LTD., EPIP , PHASE 2 , PLOT NO 81 , THANA , BADDI 173205 , DIST. SOLAN , HIMACHAL PRADESH. M HIM/COS/04/41.',
#    'Net Quantity\u200f': '\u200e370.0 millilitre',
#    'Product Dimensions\u200f': '\u200e6.2 x 4.4 x 21.5 cm; 400 Grams'},
#   'Products price': '175.77',
#   'StrikeThrough_Products_price': '189.0',
#   'Total reviews': '1031 ratings',
#   'Url': 'https://www.amazon.in/Sunsilk-Almond-Honey-Shampoo-370/dp/B08HSS5BY1/ref=sr_1_20?dchild=1&keywords=shampoo&qid=1622109910&sr=8-20',
#   'bought_together': [],
#   'brand': 'Sunsilk',
#   'icons': ['Not Returnable', 'Amazon Delivered', 'No-Contact Delivery'],
#   'misc_info': 'NA',
#   'product Title': 'Sunsilk Almond & Honey Shampoo 370 ml',
#   'subscription_discount': 'NA',
#   'variations': []},
#  {'Availability': 'NA',
#   'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'],
#   'Fullfilled': 'Fulfilled',
#   'Offer_Count': '4',
#   'Overall rating': '4.0 out of 5 stars',
#   'Product_Details': {'ASIN\u200f': '\u200eB0831B5S96',
#    'Best Sellers Rank': '#3,813 in Beauty (See Top 100 in Beauty) #355 in Shampoos (Beauty)',
#    'Country of Origin\u200f': '\u200eThailand',
#    'Date First Available\u200f': '\u200e14 December 2020',
#    'Generic Name\u200f': '\u200ePotent Aloe & Eucalyptus Shampoo, Sulphates, Silicones and Paraben Free',
#    'Importer\u200f': '\u200eIndia P&G plaza, Cardinal Gracias Road, Chakala, Andheri (E), Mumbai - 400099 India',
#    'Included Components\u200f': '\u200eShampoo',
#    'Item Dimensions LxWxH\u200f': '\u200e7.5 x 4.5 x 20.4 Centimeters',
#    'Item Weight\u200f': '\u200e400 g',
#    'Item part number\u200f': '\u200e82320232',
#    'Manufacturer\u200f': '\u200eProcter & Gamble, Procter & Gamble Manufacturing (Thailand) Ltd. Chachoengsao, 24180 Thailand.',
#    'Net Quantity\u200f': '\u200e400.0 millilitre',
#    'Packer\u200f': '\u200eProcter & Gamble Manufacturing (Thailand) Ltd. Chachoengsao, 24180 Thailand.',
#    'Product Dimensions\u200f': '\u200e7.5 x 4.5 x 20.4 cm; 400 Grams'},
#   'Products price': '638.00',
#   'StrikeThrough_Products_price': '750.0',
#   'Total reviews': '20 ratings',
#   'Url': 'https://www.amazon.in/Herbal-Essences-Eucalyptus-Sulfates-Silicone-Free/dp/B0831B5S96/ref=sr_1_21_sspa?dchild=1&keywords=shampoo&qid=1622109910&sr=8-21-spons&psc=1&qualifier=1622109910&id=8102039085665146&widgetName=sp_mtf',
#   'bought_together': [],
#   'brand': 'Herbal Essences',
#   'icons': ['Pay on Delivery',
#    'Not Returnable',
#    'Amazon Delivered',
#    'No-Contact Delivery'],
#   'misc_info': 'NA',
#   'product Title': 'Herbal Essences Real Aloe & Eucalyptus Shampoo Sulfates Paraben and Silicone-Free 400ML',
#   'subscription_discount': 'NA',
#   'variations': []},
#  {'Availability': 'NA',
#   'Category Tree': [],
#   'Fullfilled': 'NA',
#   'Offer_Count': 'NA',
#   'Overall rating': '4.4 out of 5 stars',
#   'Product_Details': {'ASIN\u200f': '\u200eB06Y3WVH2X',
#    'Batteries\u200f': '\u200e1 A batteries required.',
#    'Best Sellers Rank': '#610 in Beauty (See Top 100 in Beauty) #7 in Hair Masks & Packs #78 in Shampoos (Beauty)',
#    'Country of Origin\u200f': '\u200eIndia',
#    'Date First Available\u200f': '\u200e18 January 2018',
#    'Generic Name\u200f': '\u200eShampoo',
#    'Included Components\u200f': '\u200e1-Shampoo',
#    'Is Discontinued By Manufacturer\u200f': '\u200eNo',
#    'Item Dimensions LxWxH\u200f': '\u200e22.1 x 22.1 x 22.1 Centimeters',
#    'Item Weight\u200f': '\u200e300 g',
#    'Item model number\u200f': '\u200eA-OX Vitamino Color',
#    'Manufacturer\u200f': "\u200eL'OREAL India Pvt.Ltd.",
#    'Net Quantity\u200f': '\u200e300.0 millilitre',
#    'Product Dimensions\u200f': '\u200e22.1 x 22.1 x 22.1 cm; 300 Grams'},
#   'Products price': '665.00',
#   'StrikeThrough_Products_price': 'NA',
#   'Total reviews': '818 ratings',
#   'Url': 'https://www.amazon.in/LOrealProfessionnel-Serie-Expert-OX-Shampoo300ml/dp/B06Y3WVH2X/ref=sr_1_22_sspa?dchild=1&keywords=shampoo&qid=1622109910&sr=8-22-spons&psc=1&qualifier=1622109910&id=8102039085665146&widgetName=sp_mtf',
#   'bought_together': ["L'Oréal Professionnel Serie Expert Vitamino Masque 250 gm, For Coloured Hair",
#    "L'Oréal Professionnel Serie Expert Absolut Repair Shampoo | for Dry and Damaged Hair| Provides Deep Conditioning & Strength |",
#    "L'Oréal Professionnel Serie Expert Absolut Repair Masque 250 gm, For Dry and Damaged Hair",
#    "L'Oréal Professionnel Serie Expert Absolut Repair Serum 50 ml, For Dry and Damaged Hair",
#    "L'Oréal Professionnel Serie Expert Density Advanced Shampoo 300 ml, For Fine and Thinning Hair",
#    "L'Oréal Professionnel Serie Expert Instant Clear Shampoo | For anti-dandruff action |ZNPT + CITRIC ACID, 300ML"],
#   'brand': "L'Oréal Professionnel",
#   'icons': ['Pay on Delivery',
#    'Not Returnable',
#    'Amazon Delivered',
#    'No-Contact Delivery'],
#   'misc_info': 'NA',
#   'product Title': "L'Oréal Professionnel Serie Expert Vitamino Shampoo | For coloured hair |Protects hair colour from fading & adds shine |With Antioxidant properties",
#   'subscription_discount': '5%',
#   'variations': ['Serie Expert Vitamino Color Shampoo',
#    'Serie Expert Vitamino Color Shampoo + Masque']},
#  {'Availability': 'NA',
#   'Category Tree': ['Beauty',
#    'Hair Care & Styling',
#    'Hair Care',
#    'Conditioners'],
#   'Fullfilled': 'Fulfilled',
#   'Offer_Count': '4',
#   'Overall rating': '4.1 out of 5 stars',
#   'Product_Details': {'ASIN\u200f': '\u200eB072ZMT3NP',
#    'Best Sellers Rank': '#1,342 in Beauty (See Top 100 in Beauty) #40 in Conditioners',
#    'Country of Origin\u200f': '\u200eThailand',
#    'Date First Available\u200f': '\u200e24 July 2017',
#    'Importer\u200f': '\u200eProcter & Gamble Hygiene and Health Care Limited, P&G Plaza, Cardinal Gracias Road, Chakala, Andheri (E), Mumbai – 400099. Comments/Complaints, call CONSUMER RELATIONS on 022-24942113',
#    'Included Components\u200f': '\u200eShampoo',
#    'Is Discontinued By Manufacturer\u200f': '\u200eNo',
#    'Item Dimensions LxWxH\u200f': '\u200e7.6 x 4.3 x 20.2 Centimeters',
#    'Item Weight\u200f': '\u200e0.47 g',
#    'Item model number\u200f': '\u200e81641032',
#    'Manufacturer\u200f': '\u200eProcter & Gamble, Procter & Gamble Manufacturing (Thailand) Ltd., 112 Moo 5, Bangsamark, Bangpakong, Chachoengsao 24180 Thailand. 022-24942113',
#    'Net Quantity\u200f': '\u200e400.0 millilitre',
#    'Packer\u200f': '\u200eProcter & Gamble Home Products Private Ltd, Plot No.1, Indl Area, Villate Katha, Baddi, Dist Solan, HP-173205 Comments/Complaints, call CONSUMER RELATIONS on 022-24942113',
#    'Product Dimensions\u200f': '\u200e7.6 x 4.26 x 20.2 cm; 0.47 Grams'},
#   'Products price': '450.00',
#   'StrikeThrough_Products_price': '599.0',
#   'Total reviews': '1327 ratings',
#   'Url': 'https://www.amazon.in/White-Strawberry-Mint-Essences-Shampoo/dp/B072ZMT3NP/ref=sr_1_23_sspa?dchild=1&keywords=shampoo&qid=1622109910&sr=8-23-spons&psc=1&qualifier=1622109910&id=8102039085665146&widgetName=sp_mtf',
#   'bought_together': ['Herbal Essences White Strawberry & Sweet Mint SHAMPOO- For Cleansing and Volume - No Paraben, No Colorants, 400 ML',
#    'Herbal Essences White Strawberry & Sweet Mint CONDITIONER- For Cleansing and Volume - No Paraben, No Colorants, 400 ML',
#    'Herbal Essences Argan Oil of Morocco SHAMPOO- For Hair Repair and No Frizz- No Paraben, No Colorants, 400 ML'],
#   'brand': 'Herbal Essences',
#   'icons': ['Pay on Delivery',
#    'Not Returnable',
#    'Amazon Delivered',
#    'No-Contact Delivery'],
#   'misc_info': 'NA',
#   'product Title': 'Herbal Essences White Strawberry & Sweet Mint SHAMPOO- For Cleansing and Volume - No Paraben No Colorants 400 ML',
#   'subscription_discount': '5%',
#   'variations': []},
#  {'Availability': 'NA',
#   'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'],
#   'Fullfilled': 'Fulfilled',
#   'Offer_Count': '4',
#   'Overall rating': '3.9 out of 5 stars',
#   'Product_Details': {'ASIN\u200f': '\u200eB08CT7DP99',
#    'Best Sellers Rank': '#1,700 in Beauty (See Top 100 in Beauty) #191 in Shampoos (Beauty)',
#    'Date First Available\u200f': '\u200e12 July 2020',
#    'Generic Name\u200f': '\u200eHimalayan Rose Shampoo with Rose Hydrosol, Coconut Oil, Almond Oil & Argan Oil - For Volumnising Hair, Anti Smelly Scalp - No Parabens, Sulphate, Silicones, Color & PEG',
#    'Item Dimensions LxWxH\u200f': '\u200e50 x 50 x 145 Millimeters',
#    'Item Weight\u200f': '\u200e360 g',
#    'Item part number\u200f': '\u200eSH_ROSE',
#    'Manufacturer\u200f': '\u200eKapco International Limited, Kapco International Limited, Himachal Pradesh',
#    'Net Quantity\u200f': '\u200e300.0 millilitre',
#    'Product Dimensions\u200f': '\u200e5 x 5 x 14.5 cm; 360 Grams'},
#   'Products price': '349.00',
#   'StrikeThrough_Products_price': '449.0',
#   'Total reviews': '610 ratings',
#   'Url': 'https://www.amazon.in/WOW-Science-Himalayan-Shampoo-Hydrosol/dp/B08CT7DP99/ref=sr_1_24_sspa?dchild=1&keywords=shampoo&qid=1622109910&smid=A2WK4OB3ROODF0&sr=8-24-spons&psc=1&qualifier=1622109910&id=8102039085665146&widgetName=sp_mtf',
#   'bought_together': [],
#   'brand': 'WOW',
#   'icons': ['Pay on Delivery',
#    'Not Returnable',
#    'Amazon Delivered',
#    'No-Contact Delivery'],
#   'misc_info': 'Important informationIngredients:Shampoo',
#   'product Title': 'WOW Skin Science Himalayan Rose Shampoo with Rose Hydrosol Coconut Oil Almond Oil & Argan Oil - For Volumnising Hair Anti Smelly Scalp - No Parabens Sulphate Silicones Color & PEG 300 ml',
#   'subscription_discount': '5%',
#   'variations': ['Shampoo', 'Shampoo + Conditioner']},
#  {'Availability': 'NA',
#   'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'],
#   'Fullfilled': 'Fulfilled',
#   'Offer_Count': '4',
#   'Overall rating': '4.2 out of 5 stars',
#   'Product_Details': {'ASIN\u200f': '\u200eB07PB4G6RG',
#    'Best Sellers Rank': '#223 in Beauty (See Top 100 in Beauty) #34 in Shampoos (Beauty)',
#    'Country of Origin\u200f': '\u200eThailand',
#    'Date First Available\u200f': '\u200e27 February 2019',
#    'Generic Name\u200f': '\u200eBio Renew Argan Oil Of Morocco Shampoo',
#    'Importer\u200f': '\u200eProcter & Gamble Hygiene and Health Care Limited, P&G Plaza, Cardinal Gracias Road, Chakala, Andheri (E), Mumbai – 400099. Comments/Complaints, call CONSUMER RELATIONS on 022-24942113',
#    'Included Components\u200f': '\u200eShampoo',
#    'Item Dimensions LxWxH\u200f': '\u200e7.5 x 4.5 x 20.4 Centimeters',
#    'Item Weight\u200f': '\u200e472 g',
#    'Item part number\u200f': '\u200e82297298-1',
#    'Manufacturer\u200f': '\u200eProcter & Gamble, Procter & Gamble Manufacturing (Thailand) Ltd., 112 Moo 5, Bangsamark, Bangpakong, Chachoengsao 24180 Thailand. 022-24942113',
#    'Net Quantity\u200f': '\u200e400.0 millilitre',
#    'Packer\u200f': '\u200eProcter & Gamble Home Products Private Ltd, Plot No.1, Indl Area, Villate Katha, Baddi, Dist Solan, HP-173205 Comments/Complaints, call CONSUMER RELATIONS on 022-24942113',
#    'Product Dimensions\u200f': '\u200e7.5 x 4.5 x 20.4 cm; 472 Grams'},
#   'Products price': '420.00',
#   'StrikeThrough_Products_price': '600.0',
#   'Total reviews': '4066 ratings',
#   'Url': 'https://www.amazon.in/Herbal-Essences-bio-Morocco-Shampoo/dp/B07PB4G6RG/ref=sr_1_25?dchild=1&keywords=shampoo&qid=1622109910&sr=8-25',
#   'bought_together': ['Herbal Essences Argan Oil of Morocco SHAMPOO- For Hair Repair and No Frizz- No Paraben, No Colorants, 400 ML',
#    'Herbal Essences Argan Oil of Morocco CONDITIONER- For Hair Repair and No Frizz- No Paraben, No Colorants, 400 ML',
#    'Herbal Essences White Strawberry & Sweet Mint SHAMPOO- For Cleansing and Volume - No Paraben, No Colorants, 400 ML'],
#   'brand': 'NA',
#   'icons': ['Pay on Delivery',
#    'Not Returnable',
#    'Amazon Delivered',
#    'No-Contact Delivery'],
#   'misc_info': 'Important informationIngredients:essential antioxidants, aloe and sea kelp, ARGAN OILDirections:apply shamppo generously to wet hair, massage into a creamy lather and then rinse',
#   'product Title': 'Herbal Essences Argan Oil of Morocco SHAMPOO- For Hair Repair and No Frizz- No Paraben No Colorants 400 ML',
#   'subscription_discount': '5%',
#   'variations': ['Morocco Shampoo + Coconut Milk Conditioner',
#    'Shampoo',
#    'Shampoo + Conditioner',
#    'Shampoo + Tea Shampoo']},
#  {'Availability': 'NA',
#   'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'],
#   'Fullfilled': 'Fulfilled',
#   'Offer_Count': '4',
#   'Overall rating': '4.2 out of 5 stars',
#   'Product_Details': {'ASIN\u200f': '\u200eB07F7DRX6J',
#    'Best Sellers Rank': '#142 in Beauty (See Top 100 in Beauty) #19 in Shampoos (Beauty)',
#    'Country of Origin\u200f': '\u200eIndia',
#    'Date First Available\u200f': '\u200e3 July 2018',
#    'Generic Name\u200f': '\u200eHair Shampoo',
#    'Included Components\u200f': '\u200e1U Hair Shampoo',
#    'Is Discontinued By Manufacturer\u200f': '\u200eNo',
#    'Item Dimensions LxWxH\u200f': '\u200e44 x 78 x 222 Millimeters',
#    'Item Weight\u200f': '\u200e309 g',
#    'Item model number\u200f': '\u200eKM623',
#    'Manufacturer\u200f': '\u200eEmami Limited',
#    'Net Quantity\u200f': '\u200e340.0 millilitre',
#    'Product Dimensions\u200f': '\u200e4.4 x 7.8 x 22.2 cm; 309 Grams'},
#   'Products price': '157.00',
#   'StrikeThrough_Products_price': '196.0',
#   'Total reviews': '6501 ratings',
#   'Url': 'https://www.amazon.in/Kesh-King-Medicine-Hairfall-Shampoo/dp/B07F7DRX6J/ref=sr_1_26?dchild=1&keywords=shampoo&qid=1622109910&sr=8-26',
#   'bought_together': ['Kesh King Anti Hairfall Shampoo with aloe and 21 herbs, 340ml',
#    'Kesh King Ayurvedic Anti Hairfall Hair Oil, 300ml',
#    'Kesh King Ayurvedic Scalp and Hair Oil, 100ml'],
#   'brand': 'Kesh King',
#   'icons': ['Not Returnable', 'Amazon Delivered', 'No-Contact Delivery'],
#   'misc_info': 'Important informationIngredients:Bhringaraja (Eclipta alba),Jatamansi (Nardostachya jatamansi),Musta (Cyperus rotundus),Brahmi (Bacopa monnieri),Amalaki (Emblica officinalis) (Emblica officinalis),Nimba (Azadirachta indica),Mandukparni (Centella asiatica),,Methi (Trigonella foenum-graecum),Manjistha (Rubia cordifolia),Lodhra (Symplocos racemosa),Mehendi (Lawsonia inermis),Karanja (Pongamia pinnata),Tulasi (Ocimum sanctum),Kola (Zizyphus mauritiana),Goksura(Tribulus terrestris), Bibhitaka(Terminalia belerica),Haritaki (Terminalia chebula),Nagkesara (Mesua ferrea),Shikakai (Acacia concinna),Aloe Vera(Aloe Barbadensis),Rosemary (Rosmarinus officinalis)Directions:Apply onto wet scalp/hair gently and rinse off thoroughly after 3-4 minutes. Use thrice a week for 4 weeks followed by twice a week as maintenance therapy or as directed by a physician.',
#   'product Title': 'Kesh King Anti Hairfall Shampoo with aloe and 21 herbs 340ml',
#   'subscription_discount': '5%',
#   'variations': ['Anti Hairfall Shampoo',
#    'Anti Hairfall Shampoo + Shampoo (200ml+600ml)',
#    'Anti Hairfall Shampoo + Shampoo (340ml+600ml)']},
#  {'Availability': 'NA',
#   'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'],
#   'Fullfilled': 'Fulfilled',
#   'Offer_Count': '4',
#   'Overall rating': '4.2 out of 5 stars',
#   'Product_Details': {'ASIN\u200f': '\u200eB07MZJ62FL',
#    'Best Sellers Rank': '#53 in Beauty (See Top 100 in Beauty) #7 in Shampoos (Beauty)',
#    'Country of Origin\u200f': '\u200eIndia',
#    'Date First Available\u200f': '\u200e21 January 2019',
#    'Generic Name\u200f': '\u200eBringha Anti Hair Fall Hair Cleanser Shampoo',
#    'Item Dimensions LxWxH\u200f': '\u200e6.8 x 4.3 x 22.3 Centimeters',
#    'Item Weight\u200f': '\u200e840 g',
#    'Manufacturer\u200f': '\u200eHUL',
#    'Net Quantity\u200f': '\u200e340.0 millilitre',
#    'Product Dimensions\u200f': '\u200e6.8 x 4.3 x 22.3 cm; 840 Grams'},
#   'Products price': '298.80',
#   'StrikeThrough_Products_price': '405.0',
#   'Total reviews': '12256 ratings',
#   'Url': 'https://www.amazon.in/Indulekha-Bringha-Cleanser-Shampoo-340ml/dp/B07MZJ62FL/ref=sr_1_27?dchild=1&keywords=shampoo&qid=1622109910&sr=8-27',
#   'bought_together': ['Indulekha Bringha Shampoo, Ayurvedic Medicine For Hair Fall, Free From Parabens, Synthetic Dyes And Synthetic Perfume, 340ml',
#    'Indulekha Bringha Hair Oil Selfie Bottle',
#    'Indulekha Bringha Oil, Reduces Hair Fall And Grows New Hair, 100% Ayurvedic Oil, Free From Parabens, Sulphates, Silicones & Synthetic Dyes 50ml'],
#   'brand': 'Indulekha',
#   'icons': ['Not Returnable', 'Amazon Delivered', 'No-Contact Delivery'],
#   'misc_info': 'Important informationIndications:Apply Shampoo During Wash. Rinse It Off With WaterDirections:In Dry Place',
#   'product Title': 'Indulekha Bringha Shampoo Ayurvedic Medicine For Hair Fall Free From Parabens Synthetic Dyes And Synthetic Perfume 340ml',
#   'subscription_discount': 'NA',
#   'variations': []},
#  {'Availability': 'NA',
#   'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'],
#   'Fullfilled': 'Fulfilled',
#   'Offer_Count': '4',
#   'Overall rating': '4.2 out of 5 stars',
#   'Product_Details': {'ASIN\u200f': '\u200eB00ENZRCBI',
#    'Best Sellers Rank': '#83 in Beauty (See Top 100 in Beauty) #12 in Shampoos (Beauty)',
#    'Country of Origin\u200f': '\u200eIndia',
#    'Date First Available\u200f': '\u200e1 January 2017',
#    'Importer\u200f': '\u200eProcter & Gamble Hygiene and Health Care Limited, P&G Plaza, Cardinal Gracias Road, Chakala, Andheri (E), Mumbai – 400099. Comments/Complaints, call CONSUMER RELATIONS on 022-24942113',
#    'Included Components\u200f': '\u200eShampoo',
#    'Is Discontinued By Manufacturer\u200f': '\u200eNo',
#    'Item Dimensions LxWxH\u200f': '\u200e9 x 6.9 x 22.5 Centimeters',
#    'Item Weight\u200f': '\u200e752 g',
#    'Item model number\u200f': '\u200eH&S AHF 750ml',
#    'Manufacturer\u200f': '\u200eProcter & Gamble Home Products Private Ltd, Procter & Gamble Home Products Pvt Ltd, Plot No.1, Industrial Area, Katha, P.O.Baddi, 173205, Solan, H.P., India, 022-24942113',
#    'Net Quantity\u200f': '\u200e650.0 millilitre',
#    'Packer\u200f': '\u200eProcter & Gamble Home Products Private Ltd, Plot No.1, Indl Area, Villate Katha, Baddi, Dist Solan, HP-173205 Comments/Complaints, call CONSUMER RELATIONS on 022-24942113',
#    'Product Dimensions\u200f': '\u200e8.99 x 6.89 x 22.5 cm; 751.7 Grams'},
#   'Products price': '360.00',
#   'StrikeThrough_Products_price': '450.0',
#   'Total reviews': '6886 ratings',
#   'Url': 'https://www.amazon.in/Head-Shoulders-Hairfall-Shampoo-675ml/dp/B00ENZRCBI/ref=sr_1_28?dchild=1&keywords=shampoo&qid=1622109910&sr=8-28',
#   'bought_together': ['Head & Shoulders , Anti Dandruff Shampoo, Anti Hairfall, 650 ML',
#    'Head & Shoulders Silky Black Anti Dandruff Shampoo 650 ML',
#    'Head & Shoulders Cool Menthol Anti Dandruff Shampoo 650 ML'],
#   'brand': 'Head & Shoulders',
#   'icons': ['Pay on Delivery',
#    'Not Returnable',
#    'Amazon Delivered',
#    'No-Contact Delivery'],
#   'misc_info': 'Important informationSafety Information:Avoid contact with eyes. If this happens, rinse thoroughly with water.Directions:Shake before use. Wet hair. Gently massage onto scalp. Lather and rinse thoroughly. Repeat if desired.',
#   'product Title': 'Head & Shoulders  Anti Dandruff Shampoo Anti Hairfall 650 ML',
#   'subscription_discount': '5%',
#   'variations': ['Shampoo',
#    'Shampoo + Shampoo + Conditioner',
#    'Shampoo + Anti Dandruff Shampoo',
#    'Shampoo + Anti Hair Fall Shampoo']},
#  {'Availability': 'NA',
#   'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'],
#   'Fullfilled': 'Fulfilled',
#   'Offer_Count': '4',
#   'Overall rating': '4.3 out of 5 stars',
#   'Product_Details': {'ASIN\u200f': '\u200eB07FHD9Y8M',
#    'Best Sellers Rank': '#218 in Beauty (See Top 100 in Beauty) #33 in Shampoos (Beauty)',
#    'Country of Origin\u200f': '\u200eIndia',
#    'Date First Available\u200f': '\u200e27 June 2018',
#    'Is Discontinued By Manufacturer\u200f': '\u200eNo',
#    'Item Dimensions LxWxH\u200f': '\u200e8.6 x 5.6 x 24.1 Centimeters',
#    'Item Weight\u200f': '\u200e580 g',
#    'Item part number\u200f': '\u200e11874',
#    'Manufacturer\u200f': '\u200eHUL',
#    'Net Quantity\u200f': '\u200e580.0 millilitre',
#    'Product Dimensions\u200f': '\u200e8.6 x 5.6 x 24.1 cm; 580 Grams'},
#   'Products price': '380.00',
#   'StrikeThrough_Products_price': '410.0',
#   'Total reviews': '7024 ratings',
#   'Url': 'https://www.amazon.in/TRESemme-Keratin-Smooth-Shampoo-580ml/dp/B07FHD9Y8M/ref=sr_1_29?dchild=1&keywords=shampoo&qid=1622109910&sr=8-29',
#   'bought_together': ['Tresemme Keratin Smooth Shampoo, With Keratin And Argan Oil For Straighter, Smoother And Shinier Hair, 580 ml',
#    'Tresemme Keratin Smooth Conditioner, With Keratin And Argan Oil For Straighter, Smoother And Shinier Hair, 190 ml',
#    'Tresemme Hair Fall Defense Conditioner, With Keratin Protein, Prevents Hair Fall due to Breakage, Gives Longer & Stronger Hai'],
#   'brand': 'TRESemme',
#   'icons': ['Pay on Delivery',
#    'Not Returnable',
#    'Amazon Delivered',
#    'No-Contact Delivery'],
#   'misc_info': 'Important informationSafety Information:Avoid contact with eyes. In case of contact rinse thoroughly with waterIndications:• Apply to your wet hair and gently massage and work it into a lather. • After the application rinse thoroughly. • After rinsing shampoo, use the TRESemme Conditioner.Directions:Store in a cool and dry place.',
# ...
#    'Product Dimensions\u200f': '\u200e5.03 x 1 x 16.6 cm; 190 Grams'},
#   'Products price': '119.00',
#   'StrikeThrough_Products_price': '144.0',
#   'Total reviews': '4003 ratings',
#   'Url': 'https://www.amazon.in/Biotique-Protein-Shampoo-Intensive-Treatment/dp/B00791CQ3W/ref=sr_1_67?dchild=1&keywords=shampoo&qid=1622109983&sr=8-67',
#   'bought_together': ['Biotique Bio Kelp Protein Shampoo for Falling Hair Intensive Hair Regrowth Treatment, 190ml',
#    'Biotique Bio Mountain Ebony Vitalizing Serum For Falling Hair Intensive Hair Growth Treatment, 120ML',
#    'Biotique Bio Bhringraj Therapeutic Hair Oil for Falling Hair Intensive Hair Regrowth Treatment, 200ml'],
#   'brand': 'Biotique',
#   'icons': ['Not Returnable', 'Amazon Delivered', 'No-Contact Delivery'],
#   'misc_info': 'NA',
#   'product Title': 'Biotique Bio Kelp Protein Shampoo for Falling Hair Intensive Hair Regrowth Treatment 190ml',
#   'subscription_discount': '5%',
#   'variations': ['Shampoo',
#    'Shampoo + Ageless Serum',
#    'Shampoo + Body Building Shampoo',
#    'Shampoo + Body Wash',
#    'Shampoo + Eye Cream',
#    'Shampoo + Face Pack',
#    'Shampoo + Face Wash',
#    'Shampoo + Growth Nourishing Treatment',
#    'Shampoo + Kelp Protein Shampoo',
#    'Shampoo + Shampoo and Conditioner',
#    'Shampoo + Tan Removal Scrub, 50g',
#    'Shampoo + Tan Removal Scrub, 75g']},
#  {'Availability': 'NA',
#   'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'],
#   'Fullfilled': 'Fulfilled',
#   'Offer_Count': '4',
#   'Overall rating': '4.2 out of 5 stars',
#   'Product_Details': {'ASIN\u200f': '\u200eB08HXJT986',
#    'Best Sellers Rank': '#1,126 in Beauty (See Top 100 in Beauty) #134 in Shampoos (Beauty)',
#    'Country of Origin\u200f': '\u200eIndia',
#    'Date First Available\u200f': '\u200e12 September 2020',
#    'Generic Name\u200f': '\u200eVatika Long & Black Shampoo - Power Of 7 Natural Ingredients',
#    'Item Dimensions LxWxH\u200f': '\u200e9.4 x 7 x 25 Centimeters',
#    'Item Weight\u200f': '\u200e760 g',
#    'Item part number\u200f': '\u200eFR107640',
#    'Manufacturer\u200f': '\u200eDabur India Ltd, Dabur India Ltd , (Unit -2 ) , Integrated Industrial Area , Plot No.4 , Sector -2 , Pant nagar , Distt. Udham Singh Nagar ,Uttarakhand - 263146',
#    'Net Quantity\u200f': '\u200e640.0 millilitre',
#    'Product Dimensions\u200f': '\u200e9.4 x 7 x 25 cm; 760 Grams'},
#   'Products price': '190.00',
#   'StrikeThrough_Products_price': '380.0',
#   'Total reviews': '1174 ratings',
#   'Url': 'https://www.amazon.in/Dabur-Vatika-Shampoo-Goodness-Bhringraj/dp/B08HXJT986/ref=sr_1_68?dchild=1&keywords=shampoo&qid=1622109983&sr=8-68',
#   'bought_together': [],
#   'brand': 'DABUR',
#   'icons': ['Not Returnable', 'Amazon Delivered', 'No-Contact Delivery'],
#   'misc_info': 'NA',
#   'product Title': 'Dabur Vatika Long & Black Shampoo with the Goodness of Amla & Bhringraj for Shiny Black Hair - 640ml',
#   'subscription_discount': '5%',
#   'variations': []},
#  {'Availability': 'NA',
#   'Category Tree': [],
#   'Fullfilled': 'NA',
#   'Offer_Count': 'NA',
#   'Overall rating': '4.3 out of 5 stars',
#   'Product_Details': {'ASIN\u200f': '\u200eB0744GC2CK',
#    'Best Sellers Rank': '#93 in Beauty (See Top 100 in Beauty) #1 in Hair Masks & Packs #14 in Shampoos (Beauty)',
#    'Country of Origin\u200f': '\u200eIndia',
#    'Date First Available\u200f': '\u200e20 July 2017',
#    'Generic Name\u200f': '\u200eShampoo',
#    'Included Components\u200f': '\u200e1-Shampoo',
#    'Is Discontinued By Manufacturer\u200f': '\u200eNo',
#    'Item Dimensions LxWxH\u200f': '\u200e5.5 x 5.5 x 17 Centimeters',
#    'Item Weight\u200f': '\u200e300 g',
#    'Item model number\u200f': '\u200eSECCS250',
#    'Manufacturer\u200f': "\u200eL'OREAL India Pvt.Ltd.",
#    'Net Quantity\u200f': '\u200e1 count',
#    'Product Dimensions\u200f': '\u200e5.5 x 5.5 x 17 cm; 300 Grams'},
#   'Products price': '635.00',
#   'StrikeThrough_Products_price': 'NA',
#   'Total reviews': '1857 ratings',
#   'Url': 'https://www.amazon.in/LOreal-Professional-Absolute-Lipidium-Shampoo/dp/B0744GC2CK/ref=sr_1_69_sspa?dchild=1&keywords=shampoo&qid=1622109983&sr=8-69-spons&psc=1&qualifier=1622109983&id=7676381623506727&widgetName=sp_mtf',
#   'bought_together': ["L'Oréal Professionnel Serie Expert Absolut Repair Masque 250 gm, For Dry and Damaged Hair",
#    "L'Oréal Professionnel Serie Expert Absolut Repair Serum 50 ml, For Dry and Damaged Hair",
#    "L'Oréal Professionnel Serie Expert Instant Clear Shampoo | For anti-dandruff action |ZNPT + CITRIC ACID, 300ML",
#    "L'Oréal Professionnel Serie Expert Density Advanced Shampoo 300 ml, For Fine and Thinning Hair",
#    "L'Oreal Paris Total Repair 5 Shampoo, 1 Litre",
#    "L'Oréal Professionnel Serie Expert Liss Unlimited Shampoo | For Frizz-free Hair | Smoothens hair, controls frizz & adds shine"],
#   'brand': "L'Oréal Professionnel",
#   'icons': ['Pay on Delivery',
#    'Not Returnable',
#    'Amazon Delivered',
#    'No-Contact Delivery'],
#   'misc_info': 'NA',
#   'product Title': "L'Oréal Professionnel Serie Expert Absolut Repair Shampoo | for Dry and Damaged Hair| Provides Deep Conditioning & Strength | with Gold Quinoa & Wheat Protein",
#   'subscription_discount': '5%',
#   'variations': ['Serie Expert Absolut Repair Shampoo',
#    'Serie Expert Absolut Repair Shampoo + Masque']},
#  {'Availability': 'In stock on June 20 2021.',
#   'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'],
#   'Fullfilled': 'Fulfilled',
#   'Offer_Count': '4',
#   'Overall rating': '4.4 out of 5 stars',
#   'Product_Details': {'ASIN\u200f': '\u200eB07H9SV624',
#    'Best Sellers Rank': '#29 in Beauty (See Top 100 in Beauty) #5 in Shampoos (Beauty)',
#    'Country of Origin\u200f': '\u200eIndia',
#    'Date First Available\u200f': '\u200e13 September 2018',
#    'Item Dimensions LxWxH\u200f': '\u200e7.2 x 10.6 x 23.4 Centimeters',
#    'Item Weight\u200f': '\u200e1 kg 140 g',
#    'Item part number\u200f': '\u200e12995',
#    'Manufacturer\u200f': '\u200eHUL',
#    'Net Quantity\u200f': '\u200e1000.0 millilitre',
#    'Product Dimensions\u200f': '\u200e7.2 x 10.6 x 23.4 cm; 1.14 Kilograms'},
#   'Products price': '475.80',
#   'StrikeThrough_Products_price': '690.0',
#   'Total reviews': '13017 ratings',
#   'Url': 'https://www.amazon.in/Dove-Intense-Repair-Shampoo-1L/dp/B07H9SV624/ref=sr_1_70_sspa?dchild=1&keywords=shampoo&qid=1622109983&smid=AT95IG9ONZD7S&sr=8-70-spons&psc=1&qualifier=1622109983&id=7676381623506727&widgetName=sp_mtf',
#   'bought_together': ['Dove Intense Repair Shampoo For Damaged Hair,Enriched with Fiber Actives, Repairs Hair Damage , Makes Hair Smooth And Strong,',
#    'Dove Intense Repair Conditioner For Damaged, Frizzy Hair, Deep Nourishment For Healthy, For Smooth, Frizz Protected Hair, 175',
#    'Dove Daily Shine Shampoo - For Dull And Frizzy Hair, Makes Hair Soft, Shiny And Smooth, For Daily Use, 340 ml'],
#   'brand': 'Dove',
#   'icons': ['Pay on Delivery',
#    'Not Returnable',
#    'Amazon Delivered',
#    'No-Contact Delivery'],
#   'misc_info': "Important informationDirections:Completely soak your hair and massage your shampoo gently over your scalp. Rinse it out well. Usually rinse and repeat? For daily shampooing the rinse and repeat rule isn't actually necessary (unless you've been trigger-happy with the hairspray), so just once will do",
#   'product Title': 'Dove Intense Repair Shampoo For Damaged HairEnriched with Fiber Actives Repairs Hair Damage  Makes Hair Smooth And Strong 1 Ltr',
#   'subscription_discount': '5%',
#   'variations': []},
#  {'Availability': 'NA',
#   'Category Tree': [],
#   'Fullfilled': 'NA',
#   'Offer_Count': 'NA',
#   'Overall rating': '4.4 out of 5 stars',
#   'Product_Details': {'ASIN\u200f': '\u200eB06Y3WVH2X',
#    'Batteries\u200f': '\u200e1 A batteries required.',
#    'Best Sellers Rank': '#610 in Beauty (See Top 100 in Beauty) #7 in Hair Masks & Packs #78 in Shampoos (Beauty)',
#    'Country of Origin\u200f': '\u200eIndia',
#    'Date First Available\u200f': '\u200e18 January 2018',
#    'Generic Name\u200f': '\u200eShampoo',
#    'Included Components\u200f': '\u200e1-Shampoo',
#    'Is Discontinued By Manufacturer\u200f': '\u200eNo',
#    'Item Dimensions LxWxH\u200f': '\u200e22.1 x 22.1 x 22.1 Centimeters',
#    'Item Weight\u200f': '\u200e300 g',
#    'Item model number\u200f': '\u200eA-OX Vitamino Color',
#    'Manufacturer\u200f': "\u200eL'OREAL India Pvt.Ltd.",
#    'Net Quantity\u200f': '\u200e300.0 millilitre',
#    'Product Dimensions\u200f': '\u200e22.1 x 22.1 x 22.1 cm; 300 Grams'},
#   'Products price': '665.00',
#   'StrikeThrough_Products_price': 'NA',
#   'Total reviews': '818 ratings',
#   'Url': 'https://www.amazon.in/LOrealProfessionnel-Serie-Expert-OX-Shampoo300ml/dp/B06Y3WVH2X/ref=sr_1_71_sspa?dchild=1&keywords=shampoo&qid=1622109983&sr=8-71-spons&psc=1&qualifier=1622109983&id=7676381623506727&widgetName=sp_mtf',
#   'bought_together': ["L'Oréal Professionnel Serie Expert Vitamino Masque 250 gm, For Coloured Hair",
#    "L'Oréal Professionnel Serie Expert Absolut Repair Shampoo | for Dry and Damaged Hair| Provides Deep Conditioning & Strength |",
#    "L'Oréal Professionnel Serie Expert Absolut Repair Masque 250 gm, For Dry and Damaged Hair",
#    "L'Oréal Professionnel Serie Expert Absolut Repair Serum 50 ml, For Dry and Damaged Hair",
#    "L'Oréal Professionnel Serie Expert Density Advanced Shampoo 300 ml, For Fine and Thinning Hair",
#    "L'Oréal Professionnel Serie Expert Instant Clear Shampoo | For anti-dandruff action |ZNPT + CITRIC ACID, 300ML"],
#   'brand': "L'Oréal Professionnel",
#   'icons': ['Pay on Delivery',
#    'Not Returnable',
#    'Amazon Delivered',
#    'No-Contact Delivery'],
#   'misc_info': 'NA',
#   'product Title': "L'Oréal Professionnel Serie Expert Vitamino Shampoo | For coloured hair |Protects hair colour from fading & adds shine |With Antioxidant properties",
#   'subscription_discount': '5%',
#   'variations': ['Serie Expert Vitamino Color Shampoo',
#    'Serie Expert Vitamino Color Shampoo + Masque']},
#  {'Availability': 'NA',
#   'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'],
#   'Fullfilled': 'NA',
#   'Offer_Count': '4',
#   'Overall rating': '4.1 out of 5 stars',
#   'Product_Details': {'ASIN\u200f': '\u200eB07T4KFRT3',
#    'Best Sellers Rank': '#7,320 in Beauty (See Top 100 in Beauty) #641 in Shampoos (Beauty)',
#    'Country of Origin\u200f': '\u200eIndia',
#    'Date First Available\u200f': '\u200e13 June 2019',
#    'Generic Name\u200f': '\u200eAlmond Shampoo',
#    'Included Components\u200f': '\u200e1 Shampoo',
#    'Item Dimensions LxWxH\u200f': '\u200e6 x 3 x 15 Centimeters',
#    'Item Weight\u200f': '\u200e1 g',
#    'Item part number\u200f': '\u200e8901207025563_Fba',
#    'Manufacturer\u200f': '\u200eDabur India Limited',
#    'Net Quantity\u200f': '\u200e650.0 millilitre',
#    'Product Dimensions\u200f': '\u200e6 x 3 x 15 cm; 1 Grams'},
#   'Products price': '389.00',
#   'StrikeThrough_Products_price': '450.0',
#   'Total reviews': '473 ratings',
#   'Url': 'https://www.amazon.in/Dabur-Almond-Shampoo-Almond-Vita-Extracts/dp/B07T4KFRT3/ref=sr_1_72_sspa?dchild=1&keywords=shampoo&qid=1622109983&sr=8-72-spons&psc=1&qualifier=1622109983&id=7676381623506727&widgetName=sp_mtf',
#   'bought_together': [],
#   'brand': 'DABUR',
#   'icons': ['Not Returnable'],
#   'misc_info': 'NA',
#   'product Title': 'Dabur Almond Shampoo - With Almond-Vita Complex & Milk Extracts for Dull Dry and Weak Hair - 650 ml',
#   'subscription_discount': 'NA',
#   'variations': []},
#  {'Availability': 'NA',
#   'Category Tree': [],
#   'Fullfilled': 'NA',
#   'Offer_Count': 'NA',
#   'Overall rating': '4.4 out of 5 stars',
#   'Product_Details': {'ASIN\u200f': '\u200eB06Y3WVH2X',
#    'Batteries\u200f': '\u200e1 A batteries required.',
#    'Best Sellers Rank': '#610 in Beauty (See Top 100 in Beauty) #7 in Hair Masks & Packs #78 in Shampoos (Beauty)',
#    'Country of Origin\u200f': '\u200eIndia',
#    'Date First Available\u200f': '\u200e18 January 2018',
#    'Generic Name\u200f': '\u200eShampoo',
#    'Included Components\u200f': '\u200e1-Shampoo',
#    'Is Discontinued By Manufacturer\u200f': '\u200eNo',
#    'Item Dimensions LxWxH\u200f': '\u200e22.1 x 22.1 x 22.1 Centimeters',
#    'Item Weight\u200f': '\u200e300 g',
#    'Item model number\u200f': '\u200eA-OX Vitamino Color',
#    'Manufacturer\u200f': "\u200eL'OREAL India Pvt.Ltd.",
#    'Net Quantity\u200f': '\u200e300.0 millilitre',
#    'Product Dimensions\u200f': '\u200e22.1 x 22.1 x 22.1 cm; 300 Grams'},
#   'Products price': '665.00',
#   'StrikeThrough_Products_price': 'NA',
#   'Total reviews': '818 ratings',
#   'Url': 'https://www.amazon.in/LOrealProfessionnel-Serie-Expert-OX-Shampoo300ml/dp/B06Y3WVH2X/ref=sr_1_73?dchild=1&keywords=shampoo&qid=1622109983&sr=8-73',
#   'bought_together': ["L'Oréal Professionnel Serie Expert Vitamino Masque 250 gm, For Coloured Hair",
#    "L'Oréal Professionnel Serie Expert Absolut Repair Shampoo | for Dry and Damaged Hair| Provides Deep Conditioning & Strength |",
#    "L'Oréal Professionnel Serie Expert Absolut Repair Masque 250 gm, For Dry and Damaged Hair",
#    "L'Oréal Professionnel Serie Expert Absolut Repair Serum 50 ml, For Dry and Damaged Hair",
#    "L'Oréal Professionnel Serie Expert Density Advanced Shampoo 300 ml, For Fine and Thinning Hair",
#    "L'Oréal Professionnel Serie Expert Instant Clear Shampoo | For anti-dandruff action |ZNPT + CITRIC ACID, 300ML"],
#   'brand': "L'Oréal Professionnel",
#   'icons': ['Pay on Delivery',
#    'Not Returnable',
#    'Amazon Delivered',
#    'No-Contact Delivery'],
#   'misc_info': 'NA',
#   'product Title': "L'Oréal Professionnel Serie Expert Vitamino Shampoo | For coloured hair |Protects hair colour from fading & adds shine |With Antioxidant properties",
#   'subscription_discount': '5%',
#   'variations': ['Serie Expert Vitamino Color Shampoo',
#    'Serie Expert Vitamino Color Shampoo + Masque']},
#  {'Availability': 'NA',
#   'Category Tree': ['Beauty', 'Hair Care & Styling', 'Hair Care', 'Shampoos'],
#   'Fullfilled': 'Fulfilled',
#   'Offer_Count': '4',
#   'Overall rating': '3.9 out of 5 stars',
#   'Product_Details': {'ASIN\u200f': '\u200eB08CT7DP99',
#    'Best Sellers Rank': '#1,700 in Beauty (See Top 100 in Beauty) #191 in Shampoos (Beauty)',
#    'Date First Available\u200f': '\u200e12 July 2020',
#    'Generic Name\u200f': '\u200eHimalayan Rose Shampoo with Rose Hydrosol, Coconut Oil, Almond Oil & Argan Oil - For Volumnising Hair, Anti Smelly Scalp - No Parabens, Sulphate, Silicones, Color & PEG',
#    'Item Dimensions LxWxH\u200f': '\u200e50 x 50 x 145 Millimeters',
#    'Item Weight\u200f': '\u200e360 g',
#    'Item part number\u200f': '\u200eSH_ROSE',
#    'Manufacturer\u200f': '\u200eKapco International Limited, Kapco International Limited, Himachal Pradesh',
#    'Net Quantity\u200f': '\u200e300.0 millilitre',
#    'Product Dimensions\u200f': '\u200e5 x 5 x 14.5 cm; 360 Grams'},
#   'Products price': '349.00',
#   'StrikeThrough_Products_price': '449.0',
#   'Total reviews': '610 ratings',
#   'Url': 'https://www.amazon.in/WOW-Science-Himalayan-Shampoo-Hydrosol/dp/B08CT7DP99/ref=sr_1_74?dchild=1&keywords=shampoo&qid=1622109983&smid=A2WK4OB3ROODF0&sr=8-74',
#   'bought_together': ['WOW Apple Cider Vinegar No Parabens & Sulphate Shampoo, 300mL',
#    'WOW Skin Science Himalayan Rose Conditioner With Rose Hydrosol, Coconut Oil, Almond Oil & Argan Oil - For Volumnising Hair, A',
#    'WOW Skin Science Moroccan Argan Oil Shampoo, 300 ml',
#    'WOW Coconut Milk Shampoo, 300ml',
#    'WOW Skin Science Green Tea & Tea Tree Anti-Dandruff Shampoo - NO Sulphates, Parabens, Silicones, Color & PEG - 300 ml',
#    'WOW Skin Science Himalayan Rose Hair Mask With Rose Hydrosol, Coconut Oil, Almond Oil & Argan Oil - For Volumnising Hair, Ant'],
#   'brand': 'WOW',
#   'icons': ['Pay on Delivery',
#    'Not Returnable',
#    'Amazon Delivered',
#    'No-Contact Delivery'],
#   'misc_info': 'Important informationIngredients:Shampoo',
#   'product Title': 'WOW Skin Science Himalayan Rose Shampoo with Rose Hydrosol Coconut Oil Almond Oil & Argan Oil - For Volumnising Hair Anti Smelly Scalp - No Parabens Sulphate Silicones Color & PEG 300 ml',
#   'subscription_discount': '5%',
#   'variations': ['Shampoo', 'Shampoo + Conditioner']}]

# %%
import json
out_file = open("output_data_1.json", "w") 
    
json.dump(complete_data, out_file) 
    
out_file.close()
